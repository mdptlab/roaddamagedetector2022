# %% [markdown]
# # The data structure

# %% [markdown]
# Checkpoint and resume
# https://wandb.ai/cayush/yolov5-integration/reports/Checkpointing-YOLOv5--VmlldzoxMzA1NzQx

# %% [markdown]
# # Note:
# You have to download yolov7 to your google drive first.
# The link to that github is here: https://github.com/WongKinYiu/yolov7
# It is highly recommended to store your yolov7 code in this directory (so it will work the same as mine): MyDrive/SHSU/Codes/roaddamagedetector/yolov7

# %% [markdown]
# Training parameters and Deployment: https://blog.roboflow.com/yolov7-custom-dataset-training-tutorial/
#
# YOLOv7 page: https://github.com/WongKinYiu/yolov7

# %%
import gc

# %%
gc.collect()
# Out:
# 120

# %%
import os
os.getcwd()
# Out:
# '/home/pham/Documents/SHSU/Researching/roaddamagedetector'

# %%
cd /home/pham/Documents/SHSU/Researching/roaddamagedetector/yolov7
# Out:
# /home/pham/Documents/SHSU/Researching/roaddamagedetector/yolov7

# %%
ls
# Out:
#  bests/
#  cfg/
#  China_MotorBike0.2-best.txt
#  data/
#  deploy/
#  detect.py
#  export.py
#  figure/
#  hubconf.py
#  India0.4bestruns4_bestforall.txt
# 'India0.520-runs9-bestindividual-diffthres(0.1).txt'
#  inference/
#  Japan0.535_bestboth_runs22.txt
# 'Japan0.535-runs22-bestboth-difthres(0.05).txt'
#  LICENSE.md
#  models/
#  Norway10.4-runs4-best.txt
#  paper/
#  __pycache__/
#  README.md
#  requirements.txt
#  runs/
#  runsnotes.txt
#  scripts/
#  submission.txt
#  test.py
#  tools/
#  traced_model.pt
#  train_aux.py
#  train.py
#  United_States0.505_best_individual_trains569_en_au.txt
# 'United_States0.505_runs12_best_individual_trains569_en_au_thresdif(D00+0.1).txt'
#  United_States0.515.txt
#  utils/
#  wandb/
#  yolov7_training.pt

# %%
# Done
#!pip install -r requirements.txt

# %% [markdown]
# # Install wandb if needed

# %%
# !pip install wandb
# 9df3ad826bc10b5d5d85a1a0c93dcfbaf6f73813

# %%
#!wandb login

# %%
# download pretrain weights
#!wget https://github.com/WongKinYiu/yolov7/releases/download/v0.1/yolov7_training.pt

# %%
ls data/
# Out:
# China_MotorBike.yaml                   hyp.scratch.p6.yaml
# coco.yaml                              hyp.scratch.tiny.yaml
# Czech.yaml                             India.finetune.yaml
# hyp.scratch.custom.yaml                India.yaml
# hyp.scratch.evolve.yaml                Japan.finetune.yaml
# hyp.scratch.p5.custom.finetune.yaml    Japan.yaml
# hyp.scratch.p5.custom.newanchors.yaml  Norway1.yaml
# hyp.scratch.p5.custom.yaml             United_States.yaml
# hyp.scratch.p5.yaml

# %%
# train p5 models
# !python -m torch.distributed.launch --nproc_per_node 2 --master_port 9527 train.py --workers 8 --device 0,1 --sync-bn --batch-size 32 --data data/Norway1.yaml --img 512 960 --cfg cfg/training/yolov7-custom-CA.yaml --weights 'yolov7_training.pt' --name yolov7Norway1 --hyp data/hyp.scratch.p5.custom.yaml --label-smoothing 0.1 --epoch 250
# Out:
# /home/pham/anaconda3/lib/python3.7/site-packages/torch/distributed/launch.py:186: FutureWarning: The module torch.distributed.launch is deprecated
# and will be removed in future. Use torchrun.
# Note that --use_env is set by default in torchrun.
# If your script expects `--local_rank` argument to be set, please
# change it to read from `os.environ['LOCAL_RANK']` instead. See
# https://pytorch.org/docs/stable/distributed.html#launch-utility for
# further instructions
#
#   FutureWarning,
# WARNING:torch.distributed.run:
# *****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# YOLOR 🚀 v0.1-107-g44d8ab4 torch 1.12.1 CUDA:0 (NVIDIA RTX A4000, 16117.3125MB)
#                                        CUDA:1 (NVIDIA RTX A4000, 16108.875MB)
#
# Added key: store_based_barrier_key:1 to store for rank: 0
# Rank 0: Completed store-based barrier for key:store_based_barrier_key:1 with 2 nodes.
# Namespace(adam=False, artifact_alias='latest', batch_size=16, bbox_interval=-1, bucket='', cache_images=False, cfg='cfg/training/yolov7-custom-CA.yaml', data='data/Norway1.yaml', device='0,1', entity=None, epochs=250, evolve=False, exist_ok=False, freeze=[0], global_rank=0, hyp='data/hyp.scratch.p5.custom.yaml', image_weights=False, img_size=[512, 960], label_smoothing=0.1, linear_lr=False, local_rank=0, multi_scale=False, name='yolov7Norway1', noautoanchor=False, nosave=False, notest=False, project='runs/train', quad=False, rect=False, resume=False, save_dir='runs/train/yolov7Norway17', save_period=-1, single_cls=False, sync_bn=True, total_batch_size=32, upload_dataset=False, weights='yolov7_training.pt', workers=8, world_size=2)
# tensorboard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# hyperparameters: lr0=0.01, lrf=0.1, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.3, cls_pw=1.0, obj=0.7, obj_pw=2.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.2, scale=0.7, shear=0.01, perspective=0.0001, flipud=0.0, fliplr=0.5, mosaic=0.5, mixup=0.1, copy_paste=0.0, paste_in=0.05, loss_ota=1
# wandb: Currently logged in as: phamvanvung. Use `wandb login --relogin` to force relogin
# wandb: wandb version 0.13.3 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.13.1
# wandb: Run data is saved locally in /home/pham/Documents/SHSU/Researching/roaddamagedetector/yolov7/wandb/run-20220927_105345-2ukhcmz0
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run yolov7Norway17
# wandb: ⭐️ View project at https://wandb.ai/phamvanvung/YOLOR
# wandb: 🚀 View run at https://wandb.ai/phamvanvung/YOLOR/runs/2ukhcmz0
#
#                  from  n    params  module                                  arguments
#   0                -1  1       928  models.common.Conv                      [3, 32, 3, 1]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     36992  models.common.Conv                      [64, 64, 3, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  1      8320  models.common.Conv                      [128, 64, 1, 1]
#   5                -2  1      8320  models.common.Conv                      [128, 64, 1, 1]
#   6                -1  1     36992  models.common.Conv                      [64, 64, 3, 1]
#   7                -1  1     36992  models.common.Conv                      [64, 64, 3, 1]
#   8                -1  1     36992  models.common.Conv                      [64, 64, 3, 1]
#   9                -1  1     36992  models.common.Conv                      [64, 64, 3, 1]
#  10  [-1, -3, -5, -6]  1         0  models.common.Concat                    [1]
#  11                -1  1     66048  models.common.Conv                      [256, 256, 1, 1]
#  12                -1  1         0  models.common.MP                        []
#  13                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  14                -3  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  16          [-1, -3]  1         0  models.common.Concat                    [1]
#  17                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  18                -2  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  19                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  20                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  21                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  22                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  23  [-1, -3, -5, -6]  1         0  models.common.Concat                    [1]
#  24                -1  1    263168  models.common.Conv                      [512, 512, 1, 1]
#  25                -1  1         0  models.common.MP                        []
#  26                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  27                -3  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  28                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  29          [-1, -3]  1         0  models.common.Concat                    [1]
#  30                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  31                -2  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  32                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  33                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  34                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  35                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  36  [-1, -3, -5, -6]  1         0  models.common.Concat                    [1]
#  37                -1  1   1050624  models.common.Conv                      [1024, 1024, 1, 1]
#  38                -1  1         0  models.common.MP                        []
#  39                -1  1    525312  models.common.Conv                      [1024, 512, 1, 1]
#  40                -3  1    525312  models.common.Conv                      [1024, 512, 1, 1]
#  41                -1  1   2360320  models.common.Conv                      [512, 512, 3, 2]
#  42          [-1, -3]  1         0  models.common.Concat                    [1]
#  43                -1  1    262656  models.common.Conv                      [1024, 256, 1, 1]
#  44                -2  1    262656  models.common.Conv                      [1024, 256, 1, 1]
#  45                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  46                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  47                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  48                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  49  [-1, -3, -5, -6]  1         0  models.common.Concat                    [1]
#  50                -1  1   1050624  models.common.Conv                      [1024, 1024, 1, 1]
#  51                -1  1   7609344  models.common.SPPCSPC                   [1024, 512, 1]
#  52                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  53                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  54                37  1    262656  models.common.Conv                      [1024, 256, 1, 1]
#  55          [-1, -2]  1         0  models.common.Concat                    [1]
#  56                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  57                -2  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  58                -1  1    295168  models.common.Conv                      [256, 128, 3, 1]
#  59                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  60                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  61                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  62[-1, -2, -3, -4, -5, -6]  1         0  models.common.Concat                    [1]
#  63                -1  1    262656  models.common.Conv                      [1024, 256, 1, 1]
#  64                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  65                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  66                24  1     65792  models.common.Conv                      [512, 128, 1, 1]
#  67          [-1, -2]  1         0  models.common.Concat                    [1]
#  68                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  69                -2  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  70                -1  1     73856  models.common.Conv                      [128, 64, 3, 1]
#  71                -1  1     36992  models.common.Conv                      [64, 64, 3, 1]
#  72                -1  1     36992  models.common.Conv                      [64, 64, 3, 1]
#  73                -1  1     36992  models.common.Conv                      [64, 64, 3, 1]
#  74[-1, -2, -3, -4, -5, -6]  1         0  models.common.Concat                    [1]
#  75                -1  1     65792  models.common.Conv                      [512, 128, 1, 1]
#  76                -1  1      3352  models.common.CoordAtt                  [128, 128]
#  77                -1  1         0  models.common.MP                        []
#  78                -1  1     16640  models.common.Conv                      [128, 128, 1, 1]
#  79                -3  1     16640  models.common.Conv                      [128, 128, 1, 1]
#  80                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  81      [-1, -3, 63]  1         0  models.common.Concat                    [1]
#  82                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  83                -2  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  84                -1  1    295168  models.common.Conv                      [256, 128, 3, 1]
#  85                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  86                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  87                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  88[-1, -2, -3, -4, -5, -6]  1         0  models.common.Concat                    [1]
#  89                -1  1    262656  models.common.Conv                      [1024, 256, 1, 1]
#  90                -1  1      6680  models.common.CoordAtt                  [256, 256]
#  91                -1  1         0  models.common.MP                        []
#  92                -1  1     66048  models.common.Conv                      [256, 256, 1, 1]
#  93                -3  1     66048  models.common.Conv                      [256, 256, 1, 1]
#  94                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  95      [-1, -3, 51]  1         0  models.common.Concat                    [1]
#  96                -1  1    525312  models.common.Conv                      [1024, 512, 1, 1]
#  97                -2  1    525312  models.common.Conv                      [1024, 512, 1, 1]
#  98                -1  1   1180160  models.common.Conv                      [512, 256, 3, 1]
#  99                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
# 100                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
# 101                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
# 102[-1, -2, -3, -4, -5, -6]  1         0  models.common.Concat                    [1]
# 103                -1  1   1049600  models.common.Conv                      [2048, 512, 1, 1]
# 104                -1  1     25648  models.common.CoordAtt                  [512, 512]
# 105                76  1    328704  models.common.RepConv                   [128, 256, 3, 1]
# 106                90  1   1312768  models.common.RepConv                   [256, 512, 3, 1]
# 107               104  1   5246976  models.common.RepConv                   [512, 1024, 3, 1]
# 108   [105, 106, 107]  1     50338  models.yolo.IDetect                     [4, [[12, 16, 19, 36, 40, 28], [36, 75, 76, 55, 72, 146], [142, 110, 192, 243, 459, 401]], [256, 512, 1024]]
# Model Summary: 445 layers, 37248418 parameters, 37248418 gradients
#
# Transferred 451/599 items from yolov7_training.pt
# Scaled weight_decay = 0.0005
# Optimizer groups: 107 .bias, 104 conv.weight, 101 other
# Using SyncBatchNorm()
# train: Scanning '../RDD2022_1/Norway1/labels/train.cache' images and labels... 2
# train: Scanning '../RDD2022_1/Norway1/labels/train.cache' images and labels... 2
# val: Scanning '../RDD2022_1/Norway1/labels/val.cache' images and labels... 285 f
#
# autoanchor: Analyzing anchors... anchors/target = 4.35, Best Possible Recall (BPR) = 0.9890
# Image sizes 512 train, 960 test
# Using 8 dataloader workers
# Logging results to runs/train/yolov7Norway17
# Starting training for 250 epochs...
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      0/249     7.83G   0.07618     1.578   0.03143     1.685        57       512Reducer buckets have been rebuilt in this iteration.
#      0/249     6.46G    0.0736   0.06218   0.02911    0.1649        26       512
#                Class      Images      Labels           P           R      mAP@.5/home/pham/anaconda3/lib/python3.7/site-packages/torch/functional.py:478: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  /opt/conda/conda-bld/pytorch_1659484809535/work/aten/src/ATen/native/TensorShape.cpp:2894.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989      0.0555       0.178      0.0406     0.00958
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      1/249     8.99G   0.05402   0.01101   0.01712   0.08215        36       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989       0.172       0.193      0.0916       0.029
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      2/249       14G   0.04954   0.01181   0.01422   0.07557        25       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989       0.191       0.185       0.118      0.0314
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      3/249       14G   0.04824   0.01195   0.01392   0.07412        54       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989       0.192       0.192       0.137      0.0417
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      4/249       14G   0.04582   0.01198   0.01329   0.07109        49       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989       0.221       0.189       0.119      0.0408
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      5/249       14G   0.04464   0.01176    0.0128    0.0692        45       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989       0.344       0.196       0.184      0.0681
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      6/249       14G    0.0438   0.01194   0.01272   0.06845        36       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989       0.251       0.197       0.137      0.0509
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      7/249       14G   0.04318   0.01168   0.01261   0.06748        34       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989       0.232       0.327       0.173      0.0682
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      8/249       14G   0.04265   0.01184   0.01241    0.0669        44       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989       0.306       0.228       0.186      0.0628
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      9/249       14G   0.04227   0.01187   0.01245   0.06658        49       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989       0.308        0.29       0.188      0.0687
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     10/249       14G   0.04193   0.01167   0.01223   0.06583        40       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989       0.275       0.294       0.213      0.0787
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     11/249       14G   0.04158   0.01156    0.0122   0.06535        39       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989       0.406       0.247       0.236       0.093
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     12/249       14G   0.04137   0.01151   0.01216   0.06504        48       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989       0.379       0.283       0.222      0.0822
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     13/249       14G   0.04131   0.01171   0.01215   0.06517        32       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989       0.525        0.22       0.249      0.0946
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     14/249       14G   0.04128   0.01166   0.01217    0.0651        46       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989       0.362       0.317       0.252      0.0952
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     15/249       14G   0.04101   0.01157    0.0121   0.06469        40       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989       0.325       0.324       0.237      0.0975
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     16/249       14G   0.04101   0.01161   0.01205   0.06467        17       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989       0.304       0.325       0.248      0.0989
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     17/249       14G   0.04085   0.01153   0.01196   0.06434        17       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989       0.366       0.303        0.25      0.0985
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     18/249       14G   0.04066   0.01148   0.01204   0.06417        27       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989       0.337       0.313       0.248      0.0944
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     19/249       14G   0.04036   0.01135   0.01185   0.06356        35       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989       0.483       0.245        0.27       0.104
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     20/249       14G    0.0406   0.01139   0.01185   0.06383        39       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989       0.407       0.278       0.258       0.102
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     21/249       14G    0.0402   0.01143   0.01189   0.06352        42       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989       0.366       0.258       0.231      0.0904
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     22/249       14G    0.0403   0.01146   0.01177   0.06353        27       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989       0.358       0.281       0.247      0.0959
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     23/249       14G   0.04021   0.01144   0.01186   0.06351        69       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989       0.398       0.297       0.265       0.101
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     24/249       14G   0.04001   0.01126   0.01177   0.06305        37       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989       0.368        0.34       0.252       0.104
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     25/249       14G   0.04004   0.01133   0.01185   0.06322        33       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989       0.281        0.35       0.242      0.0979
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     26/249       14G   0.03991   0.01131   0.01175   0.06298        27       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989       0.377       0.308       0.258       0.108
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     27/249       14G   0.04003   0.01154   0.01177   0.06334        46       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989       0.376       0.287       0.253       0.106
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     28/249       14G   0.03986   0.01121   0.01172    0.0628        32       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989       0.407       0.269       0.247       0.105
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     29/249       14G   0.03959   0.01133   0.01166   0.06258        45       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989       0.467       0.285       0.272       0.115
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     30/249       14G    0.0397   0.01132   0.01173   0.06275        36       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989       0.413       0.294       0.267       0.113
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     31/249       14G   0.03948   0.01142   0.01179   0.06268        46       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989       0.459       0.265       0.261       0.112
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     32/249       14G   0.03949    0.0113   0.01163   0.06242        26       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989       0.411       0.291       0.257       0.111
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     33/249       14G    0.0396   0.01128   0.01172   0.06259        31       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989       0.417       0.303       0.271       0.113
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     34/249       14G   0.03925   0.01125   0.01172   0.06222        40       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989       0.459       0.289       0.284       0.115
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     35/249       14G   0.03935   0.01129   0.01161   0.06225        29       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989       0.447        0.31       0.286       0.116
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     36/249       14G   0.03931   0.01137   0.01156   0.06223        26       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989       0.405       0.325       0.282       0.114
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     37/249       14G   0.03915   0.01114   0.01155   0.06184        37       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989         0.5       0.266       0.283       0.113
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     38/249       14G   0.03908   0.01119   0.01153    0.0618        26       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989       0.494       0.264       0.281       0.116
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     39/249       14G   0.03903   0.01119   0.01161   0.06184        38       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989       0.388       0.318       0.285       0.116
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     40/249       14G   0.03899   0.01129   0.01162    0.0619        25       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989       0.416       0.308        0.29       0.118
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     41/249       14G   0.03922   0.01125   0.01155   0.06201        26       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989       0.427       0.316       0.289        0.12
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     42/249       14G   0.03914   0.01119   0.01159   0.06193        26       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989       0.434       0.309       0.289       0.119
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     43/249       14G   0.03912   0.01121   0.01159   0.06192        17       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989        0.41       0.334       0.295       0.119
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     44/249       14G    0.0391   0.01118   0.01164   0.06192        62       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989       0.439       0.321       0.299       0.121
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     45/249       14G   0.03894   0.01124    0.0115   0.06167        29       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989       0.426       0.328       0.299       0.123
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     46/249       14G   0.03876   0.01094   0.01153   0.06124        27       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989       0.379       0.367       0.302       0.124
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     47/249       14G   0.03891   0.01123   0.01155   0.06168        44       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989       0.363       0.375         0.3       0.121
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     48/249       14G   0.03872    0.0112   0.01148    0.0614        37       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989       0.361       0.392       0.305       0.123
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     49/249       14G   0.03859   0.01118   0.01154    0.0613        61       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989       0.345       0.409       0.307       0.123
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     50/249       14G    0.0387   0.01113   0.01144   0.06126        50       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989       0.386       0.361       0.307       0.123
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     51/249       14G   0.03863   0.01106   0.01149   0.06118        43       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989       0.346       0.397       0.308       0.123
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     52/249       14G   0.03889   0.01104   0.01157    0.0615        45       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989       0.347       0.395       0.308       0.122
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     53/249       14G   0.03865   0.01116   0.01138   0.06118        53       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989        0.36       0.377       0.305       0.121
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     54/249       14G    0.0385   0.01103   0.01137    0.0609        38       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989       0.377       0.356       0.306       0.122
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     55/249       14G   0.03855    0.0111   0.01145   0.06109        42       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989       0.396       0.353       0.307       0.122
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     56/249       14G   0.03839   0.01111    0.0114    0.0609        33       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989       0.397       0.352       0.307       0.122
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     57/249       14G   0.03842   0.01112    0.0114   0.06094        37       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989       0.399       0.354       0.309       0.122
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     58/249       14G   0.03831   0.01102   0.01136   0.06069        25       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989       0.404        0.35       0.311       0.122
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     59/249       14G   0.03837   0.01107   0.01144   0.06088        37       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989       0.402        0.35       0.311       0.123
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     60/249       14G   0.03811   0.01096    0.0113   0.06038        31       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989       0.406       0.349       0.311       0.124
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     61/249       14G    0.0382   0.01086   0.01131   0.06036        33       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989       0.405       0.349       0.311       0.124
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     62/249       14G   0.03821   0.01101    0.0114   0.06062        53       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989       0.503       0.302       0.313       0.125
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     63/249       14G    0.0381   0.01097   0.01126   0.06033        42       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989       0.409       0.345       0.312       0.124
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     64/249       14G   0.03842     0.011   0.01137   0.06079        42       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989        0.41       0.344       0.312       0.125
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     65/249       14G   0.03837   0.01102   0.01135   0.06074        32       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989       0.376       0.375       0.311       0.125
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     66/249       14G    0.0382   0.01114   0.01138   0.06072        76       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989       0.388       0.374       0.312       0.125
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     67/249       14G   0.03857   0.01108    0.0113   0.06095        31       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989       0.398       0.365       0.311       0.125
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     68/249       14G   0.03801   0.01093   0.01128   0.06021        30       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989       0.391       0.367       0.312       0.125
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     69/249       14G   0.03816   0.01095   0.01133   0.06044        29       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989       0.401       0.361       0.312       0.125
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     70/249       14G     0.038   0.01095   0.01129   0.06024        43       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989       0.408        0.36       0.313       0.126
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     71/249       14G   0.03784   0.01104   0.01126   0.06014        25       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989       0.425       0.355       0.315       0.126
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     72/249       14G   0.03804   0.01095   0.01133   0.06032        35       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989       0.426       0.355       0.315       0.127
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     73/249       14G   0.03798   0.01081   0.01134   0.06013        38       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989       0.419       0.356       0.315       0.126
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     74/249       14G   0.03802   0.01086   0.01129   0.06018        39       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989       0.419       0.357       0.317       0.127
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     75/249       14G    0.0379   0.01089   0.01129   0.06008        35       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989       0.416       0.357       0.316       0.127
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     76/249       14G   0.03765   0.01088   0.01131   0.05984        31       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989       0.415       0.357       0.316       0.128
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     77/249       14G   0.03778   0.01082    0.0113   0.05991        60       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989       0.422       0.357       0.316       0.129
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     78/249       14G   0.03764   0.01069   0.01123   0.05956        25       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989       0.419       0.357       0.316       0.128
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     79/249       14G   0.03762   0.01091    0.0112   0.05973        20       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989       0.425       0.355       0.316       0.129
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     80/249       14G   0.03772   0.01106   0.01123   0.06001        20       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989       0.425       0.354       0.316        0.13
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     81/249       14G   0.03751   0.01077   0.01118   0.05946        20       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989       0.419       0.353       0.315        0.13
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     82/249       14G   0.03771   0.01092   0.01132   0.05996        26       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989       0.401       0.361       0.316        0.13
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     83/249       14G   0.03755   0.01097    0.0112   0.05972        51       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989       0.401       0.364       0.315        0.13
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     84/249       14G    0.0376   0.01087   0.01127   0.05974        49       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989       0.398       0.363       0.311        0.13
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     85/249       14G   0.03759   0.01085   0.01122   0.05967        61       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989       0.454        0.32       0.311        0.13
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     86/249       14G   0.03773   0.01075   0.01124   0.05973        46       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989       0.459        0.32       0.311        0.13
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     87/249       14G   0.03727   0.01081    0.0112   0.05928        37       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989       0.459       0.317       0.313       0.131
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     88/249       14G   0.03744   0.01085   0.01121    0.0595        62       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989       0.531       0.292       0.314        0.13
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     89/249       14G   0.03736   0.01082    0.0112   0.05938        24       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989       0.525       0.291        0.31        0.13
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     90/249       14G   0.03723   0.01077   0.01112   0.05911        33       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989       0.533       0.293       0.317       0.132
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     91/249       14G   0.03722   0.01084   0.01119   0.05924        34       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989       0.534       0.295       0.318       0.132
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     92/249       14G   0.03724    0.0107   0.01109   0.05903        32       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989       0.521       0.297       0.316       0.132
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     93/249       14G    0.0371   0.01069   0.01118   0.05896        26       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989       0.521       0.296       0.316       0.131
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#     94/249       14G   0.03715   0.01066   0.01122   0.05903        37       512
# ...
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#    210/249       14G   0.03088  0.008982   0.01018   0.05005        28       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989       0.489       0.289       0.322       0.141
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#    211/249       14G     0.031  0.008915   0.01021   0.05012        24       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989       0.295       0.454       0.322       0.141
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#    212/249       14G   0.03083  0.008953   0.01021   0.04999        35       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989       0.306       0.438       0.317        0.14
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#    213/249       14G   0.03072  0.008894   0.01018    0.0498        43       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989        0.31       0.443       0.318        0.14
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#    214/249       14G   0.03077  0.008929   0.01014   0.04984        44       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989       0.309       0.443        0.32       0.142
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#    215/249       14G   0.03051  0.008908   0.01015   0.04956        26       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989       0.311       0.442       0.319       0.141
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#    216/249       14G   0.03081  0.008983   0.01017   0.04996        71       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989       0.307       0.444        0.32       0.141
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#    217/249       14G    0.0304  0.008916    0.0101   0.04941        39       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989       0.296       0.446       0.319        0.14
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#    218/249       14G   0.03044  0.008909   0.01015    0.0495        45       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989       0.396        0.33        0.32        0.14
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#    219/249       14G   0.03039  0.008808   0.01012   0.04932        59       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989       0.314       0.413       0.319       0.139
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#    220/249       14G   0.03033  0.008792   0.01012   0.04924        48       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989       0.316       0.411       0.319       0.139
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#    221/249       14G   0.03012  0.008647   0.01006   0.04882        33       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989       0.315       0.416       0.319       0.138
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#    222/249       14G   0.03024   0.00876    0.0101    0.0491        47       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989       0.318       0.416       0.319       0.139
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#    223/249       14G   0.02991  0.008624   0.01007   0.04861        28       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989       0.316       0.417       0.319       0.138
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#    224/249       14G   0.02998  0.008658   0.01009   0.04872        36       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989       0.322       0.416       0.319       0.138
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#    225/249       14G   0.02981  0.008703   0.01011   0.04863        39       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989       0.325       0.415       0.319       0.138
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#    226/249       14G   0.03004  0.008757    0.0101   0.04889        28       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989       0.322       0.417       0.316       0.138
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#    227/249       14G   0.02959  0.008493   0.01007   0.04816        23       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989       0.322       0.417       0.311       0.137
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#    228/249       14G   0.02964  0.008581   0.01011   0.04833        15       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989       0.319       0.417       0.311       0.137
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#    229/249       14G   0.02962  0.008618   0.01008   0.04831        32       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989       0.319       0.416       0.314       0.136
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#    230/249       14G   0.02995  0.008696    0.0101   0.04874        46       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989        0.32       0.413       0.312       0.136
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#    231/249       14G   0.02961  0.008462   0.01011   0.04818        25       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989       0.313       0.416       0.313       0.135
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#    232/249       14G   0.02948  0.008565    0.0101   0.04815        52       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989       0.302       0.419       0.314       0.135
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#    233/249       14G   0.02955  0.008581   0.01007   0.04821        55       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989       0.304        0.43       0.313       0.135
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#    234/249       14G   0.02943  0.008605   0.01008   0.04812        28       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989       0.304       0.428       0.313       0.136
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#    235/249       14G   0.02956   0.00851   0.01012   0.04819        47       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989         0.3       0.431       0.312       0.137
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#    236/249       14G    0.0294  0.008601    0.0101    0.0481        19       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989       0.288       0.434       0.311       0.137
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#    237/249       14G   0.02944  0.008683   0.01005   0.04817        45       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989       0.299       0.413        0.31       0.135
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#    238/249       14G   0.02933  0.008531   0.01004    0.0479        43       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989       0.293       0.423        0.31       0.136
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#    239/249       14G   0.02946  0.008501   0.01004   0.04799        38       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989       0.297       0.425       0.311       0.136
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#    240/249       14G   0.02921  0.008523   0.01004   0.04777        26       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989       0.292       0.414       0.309       0.134
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#    241/249       14G   0.02914  0.008582   0.01008   0.04781        44       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989        0.29       0.416       0.309       0.134
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#    242/249       14G   0.02914  0.008549   0.01005   0.04773        40       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989       0.289       0.415       0.308       0.132
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#    243/249       14G   0.02893  0.008391   0.01003   0.04735        54       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989       0.286       0.416       0.308       0.132
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#    244/249       14G   0.02907  0.008489   0.01005   0.04761        48       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989       0.316       0.371       0.308       0.133
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#    245/249       14G   0.02915  0.008439   0.01005   0.04764        29       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989       0.317       0.371       0.305       0.133
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#    246/249       14G   0.02888  0.008396   0.01002    0.0473        56       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989       0.329       0.364       0.304       0.133
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#    247/249       14G   0.02905   0.00842   0.01007   0.04755        46       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989       0.331       0.363       0.304       0.133
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#    248/249       14G   0.02863  0.008279  0.009978   0.04688        45       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989        0.33       0.363       0.306       0.132
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#    249/249       14G   0.02903  0.008387   0.01002   0.04744        40       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         285         989       0.331       0.363       0.304       0.132
#                  D00         285         771       0.495       0.638       0.574       0.277
#                  D10         285         168       0.407       0.375       0.292       0.106
#                  D20         285          23        0.16       0.217       0.129      0.0358
#                  D40         285          27        0.26       0.222       0.222        0.11
# 250 epochs completed in 24.906 hours.
#
# Optimizer stripped from runs/train/yolov7Norway17/weights/last.pt, 75.0MB
# Optimizer stripped from runs/train/yolov7Norway17/weights/best.pt, 75.0MB
# Images sizes do not match. This will causes images to be display incorrectly in the UI.
# wandb: Waiting for W&B process to finish... (success).
# wandb:
# wandb:
# wandb: Run history:
# wandb:      metrics/mAP_0.5 ▁▃▅▆▅▆▆▇▇▇▇▇▇▇▇▇▇▇▇██████████████▇▇▇▇▇▇▇
# wandb: metrics/mAP_0.5:0.95 ▁▃▅▅▅▆▆▇▇▇▇▇▇▇▇▇▇▇▇▇███▇███████████▇▇▇▇▇
# wandb:    metrics/precision ▁▂█▇▃▇▅▆▄▅▆▆▆▆██▆▇▆▆▇▇▇▇▆▆▆▇▇▇▇▄▇▄▃▄▄▄▃▄
# wandb:       metrics/recall ▁▅▂▂▅▃▄▅▇▅▅▆▆▆▄▄▅▄▅▅▄▅▅▅▆▅▅▆▅▅▅▇▄▆█▇▇█▇▆
# wandb:       train/box_loss █▅▄▄▄▄▄▄▄▄▄▄▃▃▃▃▃▃▃▃▃▃▃▃▃▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁
# wandb:       train/cls_loss █▄▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:       train/obj_loss ▇██▇▇▇▇▇▇▇▆▆▆▆▆▆▅▆▆▅▅▅▅▅▄▄▄▄▄▄▃▃▃▂▂▁▁▁▁▁
# wandb:         val/box_loss █▄▄▃▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:         val/cls_loss █▄▃▂▂▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▂▂▂▂▂▂▂▂▂▂▂
# wandb:         val/obj_loss ▄▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▂▂▂▂▂▂▃▃▃▃▄▄▄▅▅▆▆▇▇██
# wandb:                x/lr0 ▅██████▇▇▇▇▇▇▆▆▆▆▅▅▅▄▄▄▄▃▃▃▃▂▂▂▂▂▁▁▁▁▁▁▁
# wandb:                x/lr1 ▅██████▇▇▇▇▇▇▆▆▆▆▅▅▅▄▄▄▄▃▃▃▃▂▂▂▂▂▁▁▁▁▁▁▁
# wandb:                x/lr2 █▃▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:
# wandb: Run summary:
# wandb:      metrics/mAP_0.5 0.30403
# wandb: metrics/mAP_0.5:0.95 0.13223
# wandb:    metrics/precision 0.33059
# wandb:       metrics/recall 0.36319
# wandb:       train/box_loss 0.02903
# wandb:       train/cls_loss 0.01002
# wandb:       train/obj_loss 0.00839
# wandb:         val/box_loss 0.05345
# wandb:         val/cls_loss 0.01293
# wandb:         val/obj_loss 0.01037
# wandb:                x/lr0 0.001
# wandb:                x/lr1 0.001
# wandb:                x/lr2 0.001
# wandb:
# wandb: Synced yolov7Norway17: https://wandb.ai/phamvanvung/YOLOR/runs/2ukhcmz0
# wandb: Synced 6 W&B file(s), 342 media file(s), 1 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20220927_105345-2ukhcmz0/logs

# %% [markdown]
# # Inferencing

# %%
input_dir = "../RDD2022_0/"

# %%
pwd()
# Out:
# '/home/pham/Documents/SHSU/Researching/roaddamagedetector/yolov7'

# %%
# count number of images
import glob
import os
import cv2
model_name = "yolov7Norway1"
runs = "7"
c = "Norway1"
conf = 0.2
img_size = 960
# May need to do this: --save-conf
print(f'!python detect.py --weights runs/train/{model_name}{runs}/weights/best.pt --conf {conf} --img-size {img_size} --source ../RDD2022_0/{c}/test/images/ --save-txt --nosave --name {c} --save-conf')
# Out:
# !python detect.py --weights runs/train/yolov7Norway17/weights/best.pt --conf 0.2 --img-size 960 --source ../RDD2022_0/Norway1/test/images/ --save-txt --nosave --name Norway1 --save-conf

# %%
ls runs/train/yolov7Norway17/weights
# Out:
# best.pt       epoch_074.pt  epoch_174.pt  epoch_246.pt  init.pt
# epoch_000.pt  epoch_099.pt  epoch_199.pt  epoch_247.pt  last.pt
# epoch_024.pt  epoch_124.pt  epoch_224.pt  epoch_248.pt
# epoch_049.pt  epoch_149.pt  epoch_245.pt  epoch_249.pt

# %%
# !python detect.py --weights runs/train/yolov7Norway1/weights/best.pt runs/train/yolov7Norway16/weights/best.pt runs/train/yolov7Norway17/weights/best.pt --conf 0.20 --img-size 960 --source ../RDD2022_0/Norway1/test/images/ --save-txt --nosave --name Norway1 --save-conf --no-trace --augment --iou-thres 1.0
# Out:
# Namespace(agnostic_nms=False, augment=True, classes=None, conf_thres=0.2, device='', exist_ok=False, img_size=960, iou_thres=1.0, name='Norway1', no_trace=True, nosave=True, project='runs/detect', save_conf=True, save_txt=True, source='../RDD2022_0/Norway1/test/images/', update=False, view_img=False, weights=['runs/train/yolov7Norway1/weights/best.pt', 'runs/train/yolov7Norway16/weights/best.pt', 'runs/train/yolov7Norway17/weights/best.pt'])
# YOLOR 🚀 v0.1-107-g44d8ab4 torch 1.12.1 CUDA:0 (NVIDIA RTX A4000, 16117.3125MB)
#                                        CUDA:1 (NVIDIA RTX A4000, 16108.875MB)
#
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# IDetect.fuse
# Model Summary: 314 layers, 36497954 parameters, 6194944 gradients
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# IDetect.fuse
# Model Summary: 314 layers, 36497954 parameters, 6194944 gradients
# Fusing layers...
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# RepConv.fuse_repvgg_block
# IDetect.fuse
# Model Summary: 344 layers, 36533634 parameters, 6194944 gradients
# Ensemble created with ['runs/train/yolov7Norway1/weights/best.pt', 'runs/train/yolov7Norway16/weights/best.pt', 'runs/train/yolov7Norway17/weights/best.pt']
#
# /home/pham/anaconda3/lib/python3.7/site-packages/torch/functional.py:478: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  /opt/conda/conda-bld/pytorch_1659484809535/work/aten/src/ATen/native/TensorShape.cpp:2894.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# 221 D00s, 62 D20s, 6 D40s, Done. (311.0ms) Inference, (1.6ms) NMS
# 22 D40s, Done. (156.4ms) Inference, (1.0ms) NMS
# 257 D00s, 43 D20s, Done. (161.9ms) Inference, (1.1ms) NMS
# 278 D00s, Done. (170.1ms) Inference, (1.1ms) NMS
# 60 D00s, 2 D10s, 4 D40s, Done. (162.6ms) Inference, (1.0ms) NMS
# Done. (159.6ms) Inference, (0.2ms) NMS
# 39 D00s, Done. (162.4ms) Inference, (1.0ms) NMS
# Done. (155.0ms) Inference, (0.2ms) NMS
# 300 D00s, Done. (164.1ms) Inference, (1.3ms) NMS
# 124 D00s, 14 D10s, 5 D40s, Done. (158.4ms) Inference, (1.2ms) NMS
# 84 D00s, 12 D40s, Done. (161.8ms) Inference, (1.0ms) NMS
# 116 D00s, Done. (157.1ms) Inference, (1.0ms) NMS
# 188 D00s, 10 D10s, 13 D20s, 7 D40s, Done. (161.2ms) Inference, (1.1ms) NMS
# 22 D00s, 47 D10s, Done. (167.7ms) Inference, (1.0ms) NMS
# 73 D00s, Done. (156.7ms) Inference, (0.9ms) NMS
# 1 D10, Done. (158.1ms) Inference, (1.1ms) NMS
# 9 D00s, Done. (170.9ms) Inference, (1.2ms) NMS
# 12 D10s, Done. (155.7ms) Inference, (1.0ms) NMS
# 294 D00s, 6 D40s, Done. (158.6ms) Inference, (1.1ms) NMS
# 6 D00s, Done. (161.0ms) Inference, (1.1ms) NMS
# Done. (153.7ms) Inference, (0.2ms) NMS
# 1 D10, Done. (161.0ms) Inference, (1.0ms) NMS
# 16 D00s, Done. (157.0ms) Inference, (1.0ms) NMS
# 13 D00s, Done. (162.9ms) Inference, (1.0ms) NMS
# Done. (160.5ms) Inference, (0.2ms) NMS
# 3 D40s, Done. (166.5ms) Inference, (1.1ms) NMS
# 56 D00s, 85 D40s, Done. (160.1ms) Inference, (1.0ms) NMS
# 74 D00s, Done. (157.5ms) Inference, (1.0ms) NMS
# 91 D00s, Done. (162.1ms) Inference, (1.0ms) NMS
# Done. (170.6ms) Inference, (0.2ms) NMS
# 16 D00s, 5 D10s, Done. (160.0ms) Inference, (1.1ms) NMS
# 179 D00s, 2 D10s, Done. (160.8ms) Inference, (1.0ms) NMS
# 3 D00s, Done. (155.5ms) Inference, (1.0ms) NMS
# 181 D00s, Done. (156.8ms) Inference, (1.0ms) NMS
# 146 D00s, 24 D10s, 127 D20s, 3 D40s, Done. (162.0ms) Inference, (1.2ms) NMS
# 300 D00s, Done. (163.5ms) Inference, (1.1ms) NMS
# 19 D00s, 96 D10s, 8 D20s, Done. (161.4ms) Inference, (1.0ms) NMS
# Done. (163.3ms) Inference, (0.2ms) NMS
# Done. (157.3ms) Inference, (0.2ms) NMS
# 15 D00s, Done. (159.4ms) Inference, (1.2ms) NMS
# 4 D00s, Done. (153.5ms) Inference, (0.9ms) NMS
# 79 D00s, 73 D10s, Done. (156.2ms) Inference, (1.0ms) NMS
# 4 D10s, Done. (163.5ms) Inference, (1.0ms) NMS
# 22 D40s, Done. (152.7ms) Inference, (1.2ms) NMS
# Done. (154.6ms) Inference, (0.2ms) NMS
# 38 D00s, Done. (156.0ms) Inference, (1.3ms) NMS
# 73 D00s, Done. (158.5ms) Inference, (1.0ms) NMS
# Done. (158.6ms) Inference, (0.2ms) NMS
# 51 D00s, 2 D10s, Done. (157.3ms) Inference, (1.0ms) NMS
# 11 D00s, Done. (162.6ms) Inference, (1.2ms) NMS
# 13 D00s, Done. (159.1ms) Inference, (1.1ms) NMS
# 300 D00s, Done. (159.8ms) Inference, (1.0ms) NMS
# Done. (160.5ms) Inference, (0.2ms) NMS
# Done. (162.1ms) Inference, (0.2ms) NMS
# 7 D00s, Done. (152.6ms) Inference, (1.0ms) NMS
# Done. (160.9ms) Inference, (0.2ms) NMS
# 300 D00s, Done. (159.4ms) Inference, (1.0ms) NMS
# 97 D00s, 1 D10, 156 D20s, Done. (156.6ms) Inference, (1.0ms) NMS
# Done. (156.2ms) Inference, (0.2ms) NMS
# 127 D00s, 70 D10s, Done. (159.8ms) Inference, (1.0ms) NMS
# 186 D00s, 98 D20s, 16 D40s, Done. (168.2ms) Inference, (1.0ms) NMS
# 300 D00s, Done. (160.4ms) Inference, (1.1ms) NMS
# 4 D00s, Done. (158.5ms) Inference, (1.0ms) NMS
# 37 D00s, Done. (156.9ms) Inference, (0.9ms) NMS
# 198 D00s, 1 D10, Done. (160.2ms) Inference, (1.0ms) NMS
# Done. (168.9ms) Inference, (0.2ms) NMS
# 3 D10s, Done. (155.5ms) Inference, (1.1ms) NMS
# 11 D10s, Done. (156.2ms) Inference, (0.9ms) NMS
# 147 D00s, Done. (160.7ms) Inference, (1.0ms) NMS
# 4 D00s, 2 D20s, Done. (157.0ms) Inference, (1.0ms) NMS
# 283 D00s, 17 D10s, Done. (156.8ms) Inference, (1.1ms) NMS
# 300 D00s, Done. (156.1ms) Inference, (1.1ms) NMS
# Done. (157.2ms) Inference, (0.2ms) NMS
# Done. (160.2ms) Inference, (0.2ms) NMS
# 6 D00s, Done. (152.8ms) Inference, (1.0ms) NMS
# 300 D00s, Done. (161.9ms) Inference, (1.0ms) NMS
# 7 D00s, Done. (158.9ms) Inference, (1.0ms) NMS
# 80 D00s, Done. (155.3ms) Inference, (0.9ms) NMS
# 19 D00s, Done. (155.7ms) Inference, (0.9ms) NMS
# 70 D00s, 13 D10s, Done. (159.3ms) Inference, (0.9ms) NMS
# Done. (161.6ms) Inference, (0.2ms) NMS
# 288 D00s, 12 D10s, Done. (162.4ms) Inference, (1.1ms) NMS
# Done. (160.6ms) Inference, (0.2ms) NMS
# 147 D00s, 153 D10s, Done. (158.0ms) Inference, (1.1ms) NMS
# Done. (154.6ms) Inference, (0.2ms) NMS
# Done. (156.8ms) Inference, (0.2ms) NMS
# 172 D00s, 89 D10s, 39 D20s, Done. (158.6ms) Inference, (1.1ms) NMS
# 74 D00s, 5 D10s, 67 D20s, Done. (159.5ms) Inference, (1.0ms) NMS
# 300 D00s, Done. (159.6ms) Inference, (1.1ms) NMS
# Done. (156.7ms) Inference, (0.2ms) NMS
# 5 D00s, 20 D10s, Done. (165.1ms) Inference, (1.1ms) NMS
# 198 D00s, Done. (158.3ms) Inference, (1.0ms) NMS
# Done. (161.8ms) Inference, (0.2ms) NMS
# Done. (155.6ms) Inference, (0.2ms) NMS
# 4 D00s, 9 D40s, Done. (155.3ms) Inference, (1.0ms) NMS
# Done. (157.1ms) Inference, (0.2ms) NMS
# Done. (158.8ms) Inference, (0.2ms) NMS
# 6 D40s, Done. (156.4ms) Inference, (1.1ms) NMS
# 123 D00s, Done. (157.3ms) Inference, (1.0ms) NMS
# 2 D00s, Done. (158.6ms) Inference, (1.0ms) NMS
# 89 D40s, Done. (154.5ms) Inference, (1.0ms) NMS
# Done. (161.2ms) Inference, (0.2ms) NMS
# Done. (156.3ms) Inference, (0.2ms) NMS
# 97 D00s, Done. (156.5ms) Inference, (1.2ms) NMS
# 1 D00, Done. (154.4ms) Inference, (1.0ms) NMS
# 2 D10s, 73 D40s, Done. (156.1ms) Inference, (1.2ms) NMS
# 8 D00s, Done. (155.8ms) Inference, (0.9ms) NMS
# 52 D10s, 4 D40s, Done. (155.9ms) Inference, (0.9ms) NMS
# Done. (159.9ms) Inference, (0.2ms) NMS
# 164 D00s, 11 D10s, Done. (151.8ms) Inference, (0.9ms) NMS
# 289 D00s, 1 D10, 10 D20s, Done. (160.0ms) Inference, (1.1ms) NMS
# Done. (161.8ms) Inference, (0.2ms) NMS
# 12 D40s, Done. (154.3ms) Inference, (1.0ms) NMS
# 292 D00s, 8 D40s, Done. (157.1ms) Inference, (1.0ms) NMS
# Done. (160.2ms) Inference, (0.2ms) NMS
# 100 D00s, Done. (157.8ms) Inference, (1.0ms) NMS
# 62 D00s, Done. (161.2ms) Inference, (0.9ms) NMS
# Done. (155.5ms) Inference, (0.2ms) NMS
# 5 D00s, Done. (156.7ms) Inference, (1.0ms) NMS
# 14 D40s, Done. (156.8ms) Inference, (0.9ms) NMS
# 136 D00s, 159 D10s, 5 D20s, Done. (157.5ms) Inference, (1.0ms) NMS
# 52 D10s, 96 D40s, Done. (156.1ms) Inference, (1.0ms) NMS
# Done. (163.1ms) Inference, (0.2ms) NMS
# Done. (160.5ms) Inference, (0.2ms) NMS
# 43 D00s, 5 D10s, Done. (165.8ms) Inference, (1.1ms) NMS
# Done. (155.8ms) Inference, (0.2ms) NMS
# Done. (161.4ms) Inference, (0.2ms) NMS
# 145 D00s, 69 D10s, Done. (156.5ms) Inference, (1.0ms) NMS
# Done. (160.5ms) Inference, (0.2ms) NMS
# 99 D00s, 8 D20s, Done. (159.3ms) Inference, (1.1ms) NMS
# 4 D40s, Done. (156.3ms) Inference, (0.9ms) NMS
# 174 D00s, 1 D10, 125 D20s, Done. (157.1ms) Inference, (1.0ms) NMS
# 250 D00s, 50 D20s, Done. (160.8ms) Inference, (1.2ms) NMS
# 39 D00s, Done. (162.8ms) Inference, (1.0ms) NMS
# 2 D40s, Done. (155.8ms) Inference, (1.2ms) NMS
# 114 D00s, Done. (157.6ms) Inference, (1.0ms) NMS
# 2 D00s, 5 D10s, Done. (158.4ms) Inference, (1.0ms) NMS
# 13 D00s, Done. (159.8ms) Inference, (1.0ms) NMS
# 215 D00s, 1 D10, Done. (158.0ms) Inference, (1.0ms) NMS
# 6 D00s, 14 D10s, Done. (158.5ms) Inference, (1.0ms) NMS
# 1 D00, 63 D10s, Done. (155.4ms) Inference, (1.0ms) NMS
# Done. (159.8ms) Inference, (0.2ms) NMS
# Done. (158.9ms) Inference, (0.2ms) NMS
# Done. (156.8ms) Inference, (0.2ms) NMS
# 95 D00s, Done. (157.2ms) Inference, (1.0ms) NMS
# 290 D00s, 10 D10s, Done. (156.5ms) Inference, (1.1ms) NMS
# 27 D10s, Done. (159.0ms) Inference, (0.9ms) NMS
# 181 D00s, 68 D10s, 1 D20, Done. (163.2ms) Inference, (1.1ms) NMS
# 7 D00s, 1 D10, Done. (154.8ms) Inference, (0.9ms) NMS
# Done. (158.1ms) Inference, (0.2ms) NMS
# 13 D10s, 2 D40s, Done. (158.4ms) Inference, (0.9ms) NMS
# 294 D00s, 6 D10s, Done. (153.4ms) Inference, (1.0ms) NMS
# 225 D00s, 11 D10s, Done. (156.9ms) Inference, (1.0ms) NMS
# 279 D00s, 18 D10s, 3 D40s, Done. (160.5ms) Inference, (1.0ms) NMS
# 73 D00s, 138 D40s, Done. (156.3ms) Inference, (1.0ms) NMS
# 300 D00s, Done. (158.7ms) Inference, (1.0ms) NMS
# 127 D00s, Done. (162.5ms) Inference, (1.1ms) NMS
# 54 D00s, 22 D40s, Done. (159.9ms) Inference, (1.0ms) NMS
# Done. (161.6ms) Inference, (0.2ms) NMS
# 10 D00s, 86 D40s, Done. (154.1ms) Inference, (1.0ms) NMS
# 130 D00s, 9 D10s, 18 D40s, Done. (156.1ms) Inference, (1.0ms) NMS
# Done. (158.3ms) Inference, (0.2ms) NMS
# 20 D10s, Done. (160.1ms) Inference, (1.0ms) NMS
# 16 D00s, Done. (161.5ms) Inference, (1.0ms) NMS
# Done. (161.3ms) Inference, (0.2ms) NMS
# 300 D00s, Done. (158.5ms) Inference, (1.2ms) NMS
# Done. (155.2ms) Inference, (0.2ms) NMS
# 279 D00s, 21 D10s, Done. (157.4ms) Inference, (1.1ms) NMS
# 154 D00s, 4 D10s, 3 D20s, Done. (158.6ms) Inference, (1.0ms) NMS
# 12 D00s, Done. (162.4ms) Inference, (0.9ms) NMS
# 134 D00s, Done. (157.6ms) Inference, (1.0ms) NMS
# 187 D00s, 65 D10s, Done. (159.9ms) Inference, (1.1ms) NMS
# 1 D00, Done. (155.8ms) Inference, (1.1ms) NMS
# 284 D00s, 16 D40s, Done. (161.9ms) Inference, (1.1ms) NMS
# 22 D00s, Done. (154.6ms) Inference, (0.9ms) NMS
# 285 D00s, Done. (162.0ms) Inference, (1.1ms) NMS
# 15 D00s, Done. (158.8ms) Inference, (1.0ms) NMS
# 7 D40s, Done. (158.8ms) Inference, (1.1ms) NMS
# 5 D00s, 39 D10s, 13 D40s, Done. (159.2ms) Inference, (0.9ms) NMS
# 17 D00s, 6 D10s, 213 D20s, Done. (161.8ms) Inference, (1.1ms) NMS
# 6 D00s, Done. (158.5ms) Inference, (1.0ms) NMS
# 57 D00s, 24 D10s, Done. (159.5ms) Inference, (1.0ms) NMS
# Done. (160.6ms) Inference, (0.2ms) NMS
# 273 D00s, Done. (157.9ms) Inference, (1.0ms) NMS
# 10 D00s, Done. (155.9ms) Inference, (1.0ms) NMS
# 269 D00s, 31 D20s, Done. (158.0ms) Inference, (1.0ms) NMS
# 246 D00s, 1 D10, 3 D20s, Done. (165.6ms) Inference, (1.0ms) NMS
# 40 D00s, Done. (154.9ms) Inference, (0.9ms) NMS
# 4 D00s, 1 D10, Done. (154.1ms) Inference, (0.9ms) NMS
# 178 D00s, 10 D10s, Done. (157.8ms) Inference, (1.0ms) NMS
# 13 D00s, Done. (156.5ms) Inference, (0.9ms) NMS
# Done. (157.8ms) Inference, (0.2ms) NMS
# Done. (155.9ms) Inference, (0.2ms) NMS
# Done. (157.0ms) Inference, (0.2ms) NMS
# 8 D00s, Done. (155.6ms) Inference, (1.0ms) NMS
# 32 D00s, Done. (154.7ms) Inference, (1.0ms) NMS
# 13 D10s, Done. (161.7ms) Inference, (1.0ms) NMS
# 298 D00s, 2 D20s, Done. (171.9ms) Inference, (1.1ms) NMS
# 10 D00s, Done. (156.0ms) Inference, (0.9ms) NMS
# 223 D00s, 50 D10s, Done. (160.2ms) Inference, (1.1ms) NMS
# 280 D00s, 20 D10s, Done. (163.9ms) Inference, (1.0ms) NMS
# Done. (159.4ms) Inference, (0.2ms) NMS
# 28 D10s, Done. (160.7ms) Inference, (1.0ms) NMS
# 2 D00s, 3 D10s, Done. (160.3ms) Inference, (1.0ms) NMS
# Done. (156.6ms) Inference, (0.2ms) NMS
# 118 D00s, Done. (159.9ms) Inference, (1.0ms) NMS
# Done. (163.3ms) Inference, (0.2ms) NMS
# Done. (151.0ms) Inference, (0.2ms) NMS
# Done. (157.6ms) Inference, (0.2ms) NMS
# 49 D00s, Done. (156.6ms) Inference, (1.0ms) NMS
# Done. (160.6ms) Inference, (0.2ms) NMS
# 70 D00s, Done. (155.3ms) Inference, (1.0ms) NMS
# 4 D00s, 9 D10s, Done. (154.8ms) Inference, (0.9ms) NMS
# 2 D00s, Done. (160.1ms) Inference, (1.0ms) NMS
# 20 D00s, Done. (160.1ms) Inference, (1.0ms) NMS
# 28 D00s, Done. (160.3ms) Inference, (1.1ms) NMS
# Done. (159.7ms) Inference, (0.2ms) NMS
# Done. (159.0ms) Inference, (0.2ms) NMS
# 200 D00s, Done. (158.9ms) Inference, (1.0ms) NMS
# Done. (161.1ms) Inference, (0.2ms) NMS
# 41 D00s, 3 D40s, Done. (156.9ms) Inference, (1.2ms) NMS
# 193 D00s, 15 D10s, Done. (158.7ms) Inference, (1.0ms) NMS
# 286 D00s, 14 D20s, Done. (162.0ms) Inference, (1.3ms) NMS
# 278 D00s, Done. (158.0ms) Inference, (1.0ms) NMS
# Done. (155.1ms) Inference, (0.2ms) NMS
# Done. (155.5ms) Inference, (0.2ms) NMS
# 280 D00s, 20 D10s, Done. (157.4ms) Inference, (1.1ms) NMS
# 272 D00s, 28 D20s, Done. (160.4ms) Inference, (1.1ms) NMS
# 112 D00s, Done. (154.9ms) Inference, (1.1ms) NMS
# 300 D00s, Done. (160.3ms) Inference, (1.0ms) NMS
# 25 D40s, Done. (162.1ms) Inference, (1.0ms) NMS
# Done. (153.2ms) Inference, (0.2ms) NMS
# 2 D00s, Done. (158.5ms) Inference, (1.0ms) NMS
# 30 D00s, 142 D40s, Done. (158.2ms) Inference, (1.0ms) NMS
# Done. (153.1ms) Inference, (0.2ms) NMS
# 163 D00s, 45 D10s, Done. (159.7ms) Inference, (1.0ms) NMS
# Done. (159.0ms) Inference, (0.2ms) NMS
# Done. (151.7ms) Inference, (0.2ms) NMS
# 57 D00s, Done. (158.3ms) Inference, (1.0ms) NMS
# 3 D00s, Done. (161.1ms) Inference, (1.0ms) NMS
# 73 D00s, Done. (158.9ms) Inference, (1.0ms) NMS
# 96 D00s, Done. (161.9ms) Inference, (1.0ms) NMS
# Done. (157.2ms) Inference, (0.2ms) NMS
# 296 D00s, 4 D10s, Done. (157.1ms) Inference, (1.1ms) NMS
# 9 D00s, Done. (154.7ms) Inference, (0.9ms) NMS
# 9 D00s, Done. (161.1ms) Inference, (1.0ms) NMS
# 8 D00s, Done. (159.4ms) Inference, (1.0ms) NMS
# 13 D00s, 1 D10, Done. (155.0ms) Inference, (0.9ms) NMS
# 300 D00s, Done. (159.7ms) Inference, (1.0ms) NMS
# 117 D00s, Done. (162.2ms) Inference, (1.0ms) NMS
# 101 D00s, 6 D40s, Done. (155.3ms) Inference, (1.0ms) NMS
# Done. (155.8ms) Inference, (0.2ms) NMS
# 29 D00s, 3 D10s, 45 D40s, Done. (160.5ms) Inference, (1.0ms) NMS
# 239 D00s, 13 D10s, Done. (159.2ms) Inference, (1.0ms) NMS
# 26 D10s, 34 D40s, Done. (158.4ms) Inference, (1.0ms) NMS
# 83 D00s, 6 D20s, Done. (159.5ms) Inference, (1.0ms) NMS
# 5 D00s, Done. (160.8ms) Inference, (1.0ms) NMS
# 13 D00s, Done. (158.2ms) Inference, (1.0ms) NMS
# 30 D00s, Done. (155.5ms) Inference, (1.0ms) NMS
# 227 D00s, 73 D10s, Done. (155.0ms) Inference, (1.0ms) NMS
# 32 D40s, Done. (159.7ms) Inference, (0.9ms) NMS
# 23 D00s, Done. (163.0ms) Inference, (1.1ms) NMS
# 133 D00s, Done. (159.1ms) Inference, (1.2ms) NMS
# 21 D00s, Done. (158.7ms) Inference, (1.0ms) NMS
# 55 D00s, 9 D10s, 3 D40s, Done. (155.1ms) Inference, (0.9ms) NMS
# Done. (157.8ms) Inference, (0.2ms) NMS
# 3 D00s, Done. (156.2ms) Inference, (1.0ms) NMS
# 260 D00s, 40 D20s, Done. (153.9ms) Inference, (1.1ms) NMS
# 45 D00s, Done. (171.2ms) Inference, (1.1ms) NMS
# Done. (159.1ms) Inference, (0.2ms) NMS
# 3 D40s, Done. (155.6ms) Inference, (1.0ms) NMS
# 13 D00s, Done. (158.6ms) Inference, (0.9ms) NMS
# 252 D00s, 48 D20s, Done. (157.7ms) Inference, (1.0ms) NMS
# Done. (160.5ms) Inference, (0.7ms) NMS
# Done. (156.5ms) Inference, (0.2ms) NMS
# 99 D00s, Done. (155.9ms) Inference, (1.1ms) NMS
# Done. (160.6ms) Inference, (0.2ms) NMS
# Done. (159.3ms) Inference, (0.7ms) NMS
# 4 D00s, Done. (155.1ms) Inference, (0.9ms) NMS
# 300 D00s, Done. (158.9ms) Inference, (1.0ms) NMS
# Done. (160.6ms) Inference, (0.2ms) NMS
# 203 D00s, 12 D10s, 85 D20s, Done. (157.1ms) Inference, (1.2ms) NMS
# 42 D00s, 41 D10s, 1 D40, Done. (164.1ms) Inference, (1.1ms) NMS
# Done. (163.1ms) Inference, (0.2ms) NMS
# 74 D00s, Done. (159.0ms) Inference, (1.0ms) NMS
# 50 D00s, Done. (161.2ms) Inference, (0.9ms) NMS
# 206 D00s, 94 D10s, Done. (160.6ms) Inference, (1.1ms) NMS
# 14 D00s, 4 D10s, 2 D40s, Done. (161.9ms) Inference, (1.0ms) NMS
# 196 D00s, Done. (162.0ms) Inference, (1.0ms) NMS
# Done. (161.8ms) Inference, (0.2ms) NMS
# 24 D40s, Done. (154.6ms) Inference, (1.0ms) NMS
# 123 D00s, Done. (154.5ms) Inference, (0.9ms) NMS
# 2 D00s, 35 D40s, Done. (159.9ms) Inference, (1.0ms) NMS
# 76 D00s, 22 D10s, Done. (158.9ms) Inference, (1.0ms) NMS
# 285 D00s, 11 D10s, 4 D20s, Done. (155.8ms) Inference, (1.0ms) NMS
# Done. (162.4ms) Inference, (0.2ms) NMS
# 83 D00s, Done. (153.6ms) Inference, (1.0ms) NMS
# Done. (163.1ms) Inference, (0.2ms) NMS
# 129 D00s, Done. (154.9ms) Inference, (1.1ms) NMS
# Done. (163.5ms) Inference, (0.2ms) NMS
# 17 D00s, 2 D10s, Done. (153.8ms) Inference, (1.0ms) NMS
# 177 D00s, 114 D40s, Done. (158.2ms) Inference, (1.0ms) NMS
# 72 D00s, Done. (163.1ms) Inference, (1.0ms) NMS
# 206 D00s, 70 D10s, 24 D20s, Done. (159.6ms) Inference, (1.1ms) NMS
# 295 D00s, 1 D10, 4 D20s, Done. (162.6ms) Inference, (1.1ms) NMS
# 50 D00s, Done. (165.8ms) Inference, (1.0ms) NMS
# Done. (170.6ms) Inference, (0.2ms) NMS
# 283 D00s, 17 D20s, Done. (174.7ms) Inference, (1.1ms) NMS
# Done. (170.1ms) Inference, (0.2ms) NMS
# 78 D00s, Done. (168.7ms) Inference, (1.1ms) NMS
# 180 D00s, 22 D20s, 9 D40s, Done. (148.1ms) Inference, (0.8ms) NMS
# 293 D00s, 1 D10, 6 D20s, Done. (140.3ms) Inference, (0.9ms) NMS
# 96 D00s, Done. (150.8ms) Inference, (0.8ms) NMS
# 55 D00s, 21 D10s, Done. (142.9ms) Inference, (0.9ms) NMS
# 3 D00s, Done. (136.3ms) Inference, (0.8ms) NMS
# 26 D00s, 1 D10, 9 D20s, Done. (140.9ms) Inference, (0.8ms) NMS
# 2 D00s, Done. (142.7ms) Inference, (0.8ms) NMS
# Done. (141.1ms) Inference, (0.2ms) NMS
# 300 D00s, Done. (136.8ms) Inference, (0.8ms) NMS
# Done. (139.1ms) Inference, (0.2ms) NMS
# Done. (138.5ms) Inference, (0.2ms) NMS
# 16 D00s, Done. (139.0ms) Inference, (0.8ms) NMS
# 16 D40s, Done. (141.0ms) Inference, (0.8ms) NMS
# 300 D00s, Done. (140.5ms) Inference, (0.8ms) NMS
# 5 D40s, Done. (138.0ms) Inference, (0.7ms) NMS
# 143 D00s, Done. (137.4ms) Inference, (0.8ms) NMS
# 248 D00s, 1 D10, 51 D40s, Done. (136.7ms) Inference, (0.9ms) NMS
# 291 D00s, 9 D10s, Done. (140.6ms) Inference, (0.9ms) NMS
# 135 D00s, Done. (136.0ms) Inference, (0.8ms) NMS
# 228 D00s, Done. (137.8ms) Inference, (0.7ms) NMS
# 1 D00, Done. (139.0ms) Inference, (0.8ms) NMS
# 2 D00s, Done. (138.9ms) Inference, (0.8ms) NMS
# 121 D00s, Done. (139.0ms) Inference, (0.8ms) NMS
# 27 D00s, Done. (136.6ms) Inference, (0.7ms) NMS
# 9 D00s, 2 D40s, Done. (139.0ms) Inference, (0.8ms) NMS
# 132 D00s, Done. (133.0ms) Inference, (0.7ms) NMS
# 41 D00s, Done. (137.6ms) Inference, (0.7ms) NMS
# 5 D00s, Done. (140.4ms) Inference, (0.8ms) NMS
# 20 D20s, Done. (139.7ms) Inference, (0.8ms) NMS
# Done. (136.9ms) Inference, (0.1ms) NMS
# Done. (141.4ms) Inference, (0.2ms) NMS
# 110 D00s, Done. (141.1ms) Inference, (0.8ms) NMS
# 49 D10s, 2 D20s, Done. (141.0ms) Inference, (0.8ms) NMS
# 300 D00s, Done. (137.7ms) Inference, (0.8ms) NMS
# 4 D00s, Done. (141.8ms) Inference, (0.8ms) NMS
# 109 D00s, 1 D10, 1 D20, Done. (137.6ms) Inference, (0.8ms) NMS
# 81 D00s, Done. (142.0ms) Inference, (0.8ms) NMS
# 39 D00s, Done. (140.9ms) Inference, (0.7ms) NMS
# 2 D00s, Done. (139.0ms) Inference, (0.8ms) NMS
# Done. (137.4ms) Inference, (0.1ms) NMS
# 61 D00s, 1 D40, Done. (140.4ms) Inference, (0.7ms) NMS
# 48 D00s, 72 D10s, 47 D20s, 36 D40s, Done. (138.4ms) Inference, (0.8ms) NMS
# 3 D10s, Done. (139.1ms) Inference, (0.8ms) NMS
# 300 D00s, Done. (141.7ms) Inference, (0.8ms) NMS
# 42 D00s, Done. (141.2ms) Inference, (0.8ms) NMS
# 2 D10s, 23 D40s, Done. (140.3ms) Inference, (0.8ms) NMS
# 6 D00s, Done. (142.1ms) Inference, (0.9ms) NMS
# 300 D00s, Done. (141.9ms) Inference, (0.9ms) NMS
# 112 D00s, 76 D40s, Done. (138.9ms) Inference, (0.8ms) NMS
# 203 D00s, 40 D10s, 57 D40s, Done. (138.9ms) Inference, (0.8ms) NMS
# 119 D00s, 16 D10s, Done. (140.7ms) Inference, (0.8ms) NMS
# 5 D00s, Done. (139.7ms) Inference, (0.8ms) NMS
# 24 D00s, Done. (138.1ms) Inference, (0.8ms) NMS
# 15 D00s, 31 D10s, Done. (140.3ms) Inference, (0.7ms) NMS
# 16 D00s, Done. (140.2ms) Inference, (0.8ms) NMS
# 6 D00s, 2 D40s, Done. (136.3ms) Inference, (0.7ms) NMS
# 8 D00s, Done. (137.9ms) Inference, (0.8ms) NMS
# 108 D00s, 143 D20s, 6 D40s, Done. (135.2ms) Inference, (0.8ms) NMS
# 6 D00s, Done. (140.8ms) Inference, (0.9ms) NMS
# 148 D10s, Done. (137.9ms) Inference, (0.7ms) NMS
# 137 D00s, Done. (142.8ms) Inference, (0.8ms) NMS
# 295 D00s, 5 D10s, Done. (141.6ms) Inference, (1.0ms) NMS
# 163 D00s, 56 D40s, Done. (139.2ms) Inference, (0.8ms) NMS
# 224 D00s, 33 D10s, Done. (144.6ms) Inference, (0.8ms) NMS
# 204 D00s, Done. (140.0ms) Inference, (0.8ms) NMS
# Done. (140.8ms) Inference, (0.2ms) NMS
# 2 D10s, Done. (139.0ms) Inference, (0.8ms) NMS
# 14 D00s, Done. (136.9ms) Inference, (0.7ms) NMS
# 19 D00s, Done. (140.5ms) Inference, (0.8ms) NMS
# 300 D00s, Done. (139.7ms) Inference, (0.8ms) NMS
# 4 D00s, Done. (139.9ms) Inference, (0.8ms) NMS
# 296 D00s, 4 D40s, Done. (138.7ms) Inference, (0.8ms) NMS
# Done. (137.5ms) Inference, (0.2ms) NMS
# Done. (140.4ms) Inference, (0.2ms) NMS
# Done. (140.3ms) Inference, (0.2ms) NMS
# 80 D00s, 97 D20s, Done. (133.3ms) Inference, (0.8ms) NMS
# 1 D00, Done. (139.6ms) Inference, (0.7ms) NMS
# 300 D00s, Done. (140.3ms) Inference, (0.9ms) NMS
# 2 D00s, Done. (141.0ms) Inference, (0.8ms) NMS
# 56 D00s, 3 D10s, Done. (136.0ms) Inference, (0.7ms) NMS
# 22 D00s, Done. (135.8ms) Inference, (0.8ms) NMS
# 278 D00s, 22 D10s, Done. (135.8ms) Inference, (0.8ms) NMS
# 105 D00s, 1 D10, Done. (137.9ms) Inference, (0.8ms) NMS
# 6 D00s, 9 D10s, 27 D40s, Done. (138.9ms) Inference, (0.8ms) NMS
# Done. (139.0ms) Inference, (0.2ms) NMS
# 20 D00s, Done. (138.7ms) Inference, (0.7ms) NMS
# 3 D10s, Done. (139.3ms) Inference, (0.7ms) NMS
# Done. (141.1ms) Inference, (0.2ms) NMS
# 186 D00s, Done. (138.9ms) Inference, (0.8ms) NMS
# 36 D00s, Done. (143.2ms) Inference, (0.8ms) NMS
# 31 D00s, Done. (140.8ms) Inference, (0.8ms) NMS
# 300 D00s, Done. (139.0ms) Inference, (0.9ms) NMS
# 270 D00s, Done. (139.5ms) Inference, (0.8ms) NMS
# 45 D00s, Done. (142.0ms) Inference, (0.8ms) NMS
# 130 D00s, Done. (140.6ms) Inference, (0.8ms) NMS
# Done. (137.4ms) Inference, (0.1ms) NMS
# 16 D00s, Done. (140.6ms) Inference, (0.8ms) NMS
# 71 D00s, 63 D40s, Done. (145.9ms) Inference, (0.9ms) NMS
# 7 D10s, Done. (139.6ms) Inference, (0.8ms) NMS
# 1 D00, Done. (138.4ms) Inference, (0.9ms) NMS
# 89 D00s, Done. (141.3ms) Inference, (0.8ms) NMS
# 83 D00s, 14 D10s, Done. (140.9ms) Inference, (0.8ms) NMS
# 4 D00s, 138 D10s, Done. (137.4ms) Inference, (0.8ms) NMS
# 58 D00s, 3 D10s, 88 D40s, Done. (140.9ms) Inference, (0.8ms) NMS
# 207 D00s, 31 D10s, Done. (142.9ms) Inference, (0.8ms) NMS
# 139 D00s, Done. (139.4ms) Inference, (0.8ms) NMS
# Done. (141.9ms) Inference, (0.2ms) NMS
# Done. (136.6ms) Inference, (0.1ms) NMS
# 38 D00s, Done. (139.0ms) Inference, (0.7ms) NMS
# 300 D00s, Done. (141.5ms) Inference, (0.9ms) NMS
# 1 D40, Done. (139.5ms) Inference, (0.8ms) NMS
# 18 D10s, Done. (139.5ms) Inference, (0.8ms) NMS
# 114 D00s, Done. (139.3ms) Inference, (0.8ms) NMS
# 38 D00s, Done. (142.3ms) Inference, (0.8ms) NMS
# 12 D00s, 2 D40s, Done. (134.2ms) Inference, (0.8ms) NMS
# Done. (139.9ms) Inference, (0.2ms) NMS
# 122 D00s, 30 D40s, Done. (136.9ms) Inference, (0.8ms) NMS
# 38 D10s, 1 D40, Done. (137.7ms) Inference, (0.8ms) NMS
# 25 D00s, Done. (142.7ms) Inference, (0.8ms) NMS
# 300 D00s, Done. (140.9ms) Inference, (0.8ms) NMS
# 1 D00, 31 D10s, 10 D20s, 237 D40s, Done. (141.4ms) Inference, (0.8ms) NMS
# 9 D00s, Done. (140.8ms) Inference, (0.8ms) NMS
# 144 D00s, Done. (137.4ms) Inference, (0.8ms) NMS
# 238 D00s, 62 D20s, Done. (139.0ms) Inference, (0.9ms) NMS
# 78 D00s, Done. (135.4ms) Inference, (0.7ms) NMS
# 43 D00s, Done. (135.6ms) Inference, (0.8ms) NMS
# 300 D00s, Done. (137.9ms) Inference, (0.8ms) NMS
# 161 D00s, 11 D40s, Done. (140.6ms) Inference, (0.8ms) NMS
# 5 D00s, Done. (138.3ms) Inference, (0.8ms) NMS
# Done. (136.5ms) Inference, (0.1ms) NMS
# 60 D00s, Done. (140.0ms) Inference, (0.8ms) NMS
# 209 D00s, 6 D10s, 3 D40s, Done. (139.4ms) Inference, (0.8ms) NMS
# 101 D00s, Done. (142.5ms) Inference, (0.8ms) NMS
# 300 D00s, Done. (136.2ms) Inference, (1.0ms) NMS
# 159 D00s, 7 D10s, Done. (138.2ms) Inference, (0.8ms) NMS
# 2 D00s, Done. (140.2ms) Inference, (0.8ms) NMS
# 80 D00s, Done. (138.3ms) Inference, (0.7ms) NMS
# 204 D00s, Done. (136.0ms) Inference, (0.8ms) NMS
# Done. (135.9ms) Inference, (0.2ms) NMS
# 165 D00s, 1 D10, 77 D20s, Done. (136.9ms) Inference, (0.8ms) NMS
# Done. (139.1ms) Inference, (0.2ms) NMS
# 48 D00s, Done. (137.0ms) Inference, (0.8ms) NMS
# 75 D00s, Done. (139.1ms) Inference, (0.8ms) NMS
# 77 D00s, Done. (139.2ms) Inference, (0.8ms) NMS
# Done. (137.6ms) Inference, (0.2ms) NMS
# Done. (135.1ms) Inference, (0.2ms) NMS
# Done. (141.9ms) Inference, (0.2ms) NMS
# 296 D00s, 4 D10s, Done. (140.6ms) Inference, (0.8ms) NMS
# 71 D00s, 44 D40s, Done. (138.2ms) Inference, (0.8ms) NMS
# 137 D00s, Done. (137.2ms) Inference, (0.8ms) NMS
# 2 D00s, Done. (141.4ms) Inference, (0.8ms) NMS
# 1 D00, Done. (136.4ms) Inference, (0.8ms) NMS
# Done. (141.3ms) Inference, (0.2ms) NMS
# 55 D00s, Done. (142.3ms) Inference, (0.9ms) NMS
# 251 D00s, 5 D10s, 28 D40s, Done. (141.4ms) Inference, (0.8ms) NMS
# Done. (139.7ms) Inference, (0.2ms) NMS
# 23 D00s, Done. (137.5ms) Inference, (0.8ms) NMS
# Done. (139.0ms) Inference, (0.2ms) NMS
# Done. (140.1ms) Inference, (0.2ms) NMS
# Done. (140.4ms) Inference, (0.2ms) NMS
# 3 D00s, Done. (138.3ms) Inference, (0.9ms) NMS
# 298 D00s, 2 D20s, Done. (140.1ms) Inference, (1.1ms) NMS
# Done. (139.4ms) Inference, (0.2ms) NMS
# Done. (138.3ms) Inference, (0.2ms) NMS
# 136 D00s, Done. (139.3ms) Inference, (0.7ms) NMS
# 252 D00s, 9 D10s, 39 D20s, Done. (137.9ms) Inference, (0.8ms) NMS
# 96 D00s, Done. (140.6ms) Inference, (0.8ms) NMS
# Done. (138.9ms) Inference, (0.1ms) NMS
# 3 D00s, Done. (136.4ms) Inference, (0.8ms) NMS
# 115 D00s, Done. (138.5ms) Inference, (0.8ms) NMS
# 243 D00s, 21 D10s, 36 D20s, Done. (138.5ms) Inference, (0.8ms) NMS
# 5 D00s, Done. (142.9ms) Inference, (0.8ms) NMS
# 3 D00s, 4 D10s, Done. (136.8ms) Inference, (0.7ms) NMS
# 300 D00s, Done. (136.8ms) Inference, (0.8ms) NMS
# Done. (140.8ms) Inference, (0.2ms) NMS
# 29 D00s, Done. (138.2ms) Inference, (0.8ms) NMS
# 19 D00s, 12 D10s, Done. (140.1ms) Inference, (0.8ms) NMS
# 270 D00s, 30 D10s, Done. (139.5ms) Inference, (0.8ms) NMS
# Done. (140.8ms) Inference, (0.2ms) NMS
# 298 D00s, 2 D10s, Done. (140.8ms) Inference, (1.1ms) NMS
# 300 D00s, Done. (138.0ms) Inference, (0.9ms) NMS
# 1 D00, 51 D10s, 1 D40, Done. (141.4ms) Inference, (0.8ms) NMS
# 299 D00s, 1 D10, Done. (138.9ms) Inference, (1.0ms) NMS
# Done. (136.6ms) Inference, (0.2ms) NMS
# Done. (135.8ms) Inference, (0.2ms) NMS
# Done. (138.1ms) Inference, (0.2ms) NMS
# 95 D00s, 2 D10s, Done. (135.6ms) Inference, (0.7ms) NMS
# 11 D10s, Done. (138.5ms) Inference, (0.8ms) NMS
# Done. (143.1ms) Inference, (0.2ms) NMS
# 4 D00s, Done. (137.0ms) Inference, (0.8ms) NMS
# 124 D00s, Done. (140.1ms) Inference, (0.8ms) NMS
# 3 D10s, 13 D40s, Done. (137.8ms) Inference, (0.7ms) NMS
# 300 D00s, Done. (139.3ms) Inference, (1.0ms) NMS
# 44 D00s, Done. (138.1ms) Inference, (0.8ms) NMS
# 252 D00s, Done. (139.0ms) Inference, (0.8ms) NMS
# Done. (136.8ms) Inference, (0.2ms) NMS
# 18 D00s, 10 D10s, Done. (134.8ms) Inference, (0.7ms) NMS
# 72 D00s, Done. (136.5ms) Inference, (0.8ms) NMS
# 179 D00s, Done. (139.2ms) Inference, (0.8ms) NMS
# Done. (140.9ms) Inference, (0.2ms) NMS
# 82 D00s, Done. (140.8ms) Inference, (0.8ms) NMS
# 24 D00s, 33 D10s, Done. (148.8ms) Inference, (0.9ms) NMS
# 5 D00s, Done. (141.1ms) Inference, (0.8ms) NMS
# Done. (138.9ms) Inference, (0.2ms) NMS
# 52 D00s, Done. (135.4ms) Inference, (0.7ms) NMS
# Done. (135.1ms) Inference, (0.1ms) NMS
# 300 D00s, Done. (140.2ms) Inference, (0.9ms) NMS
# 2 D10s, Done. (139.1ms) Inference, (0.8ms) NMS
# 300 D00s, Done. (141.2ms) Inference, (0.9ms) NMS
# 89 D00s, Done. (138.9ms) Inference, (0.8ms) NMS
# 112 D00s, Done. (137.8ms) Inference, (0.8ms) NMS
# Done. (133.0ms) Inference, (0.1ms) NMS
# 2 D40s, Done. (139.1ms) Inference, (0.8ms) NMS
# Done. (141.0ms) Inference, (0.2ms) NMS
# 85 D00s, Done. (140.6ms) Inference, (0.8ms) NMS
# 146 D00s, Done. (137.5ms) Inference, (0.8ms) NMS
# 235 D00s, Done. (134.2ms) Inference, (0.8ms) NMS
# 41 D10s, Done. (138.7ms) Inference, (0.8ms) NMS
# 88 D00s, 64 D10s, Done. (142.7ms) Inference, (0.9ms) NMS
# 79 D00s, Done. (142.0ms) Inference, (0.8ms) NMS
# Done. (141.4ms) Inference, (0.2ms) NMS
# 155 D00s, 4 D40s, Done. (141.2ms) Inference, (0.8ms) NMS
# 32 D10s, 3 D20s, Done. (139.4ms) Inference, (0.8ms) NMS
# 1 D10, Done. (139.1ms) Inference, (0.8ms) NMS
# 300 D00s, Done. (139.0ms) Inference, (0.8ms) NMS
# 296 D00s, 4 D10s, Done. (137.7ms) Inference, (1.0ms) NMS
# Done. (140.7ms) Inference, (0.2ms) NMS
# 65 D00s, Done. (138.8ms) Inference, (0.9ms) NMS
# 45 D00s, 1 D10, Done. (135.8ms) Inference, (0.8ms) NMS
# Done. (137.1ms) Inference, (0.2ms) NMS
# 265 D00s, 35 D40s, Done. (139.4ms) Inference, (0.9ms) NMS
# Done. (141.7ms) Inference, (0.2ms) NMS
# Done. (140.4ms) Inference, (0.2ms) NMS
# Done. (142.3ms) Inference, (0.2ms) NMS
# 13 D00s, Done. (140.5ms) Inference, (0.8ms) NMS
# Done. (137.6ms) Inference, (0.1ms) NMS
# 48 D00s, 51 D20s, 201 D40s, Done. (138.5ms) Inference, (0.9ms) NMS
# 10 D40s, Done. (141.0ms) Inference, (0.8ms) NMS
# 5 D10s, Done. (137.5ms) Inference, (0.8ms) NMS
# Done. (138.7ms) Inference, (0.2ms) NMS
# 299 D00s, 1 D40, Done. (134.4ms) Inference, (0.9ms) NMS
# 30 D00s, Done. (134.9ms) Inference, (0.7ms) NMS
# 8 D00s, Done. (135.4ms) Inference, (0.8ms) NMS
# Done. (139.6ms) Inference, (0.2ms) NMS
# 221 D00s, Done. (134.1ms) Inference, (0.8ms) NMS
# 120 D00s, Done. (141.3ms) Inference, (0.8ms) NMS
# 227 D00s, 14 D10s, Done. (142.9ms) Inference, (0.9ms) NMS
# 58 D00s, Done. (139.6ms) Inference, (0.8ms) NMS
# 6 D00s, Done. (140.5ms) Inference, (0.8ms) NMS
# 29 D00s, Done. (140.8ms) Inference, (0.7ms) NMS
# 89 D00s, 2 D10s, Done. (135.1ms) Inference, (0.7ms) NMS
# 83 D00s, Done. (139.7ms) Inference, (0.8ms) NMS
# 1 D00, Done. (138.6ms) Inference, (0.8ms) NMS
# 17 D20s, Done. (140.5ms) Inference, (0.8ms) NMS
# 300 D00s, Done. (136.5ms) Inference, (0.8ms) NMS
# 4 D00s, 3 D40s, Done. (138.7ms) Inference, (0.8ms) NMS
# 4 D00s, 1 D40, Done. (138.3ms) Inference, (0.8ms) NMS
# 177 D00s, 15 D10s, 30 D40s, Done. (141.9ms) Inference, (0.8ms) NMS
# 300 D00s, Done. (144.6ms) Inference, (0.8ms) NMS
# 279 D00s, 21 D10s, Done. (137.2ms) Inference, (0.8ms) NMS
# Done. (137.6ms) Inference, (0.2ms) NMS
# Done. (137.3ms) Inference, (0.2ms) NMS
# 266 D00s, 24 D10s, 10 D20s, Done. (140.8ms) Inference, (0.9ms) NMS
# 35 D00s, 13 D40s, Done. (139.4ms) Inference, (0.7ms) NMS
# 6 D40s, Done. (136.6ms) Inference, (0.8ms) NMS
# 109 D00s, 8 D10s, 35 D40s, Done. (136.4ms) Inference, (0.8ms) NMS
# Done. (142.5ms) Inference, (0.2ms) NMS
# 2 D10s, 4 D40s, Done. (133.7ms) Inference, (0.8ms) NMS
# Done. (136.7ms) Inference, (0.1ms) NMS
# Done. (140.6ms) Inference, (0.2ms) NMS
# 177 D00s, 8 D40s, Done. (136.2ms) Inference, (0.7ms) NMS
# 16 D00s, Done. (135.9ms) Inference, (0.7ms) NMS
# 43 D40s, Done. (135.4ms) Inference, (0.7ms) NMS
# 11 D00s, 75 D10s, Done. (138.3ms) Inference, (0.8ms) NMS
# 2 D00s, Done. (139.4ms) Inference, (0.8ms) NMS
# 129 D00s, 10 D10s, 161 D40s, Done. (138.8ms) Inference, (0.8ms) NMS
# 300 D00s, Done. (139.8ms) Inference, (0.9ms) NMS
# Done. (143.7ms) Inference, (0.2ms) NMS
# 9 D00s, Done. (135.4ms) Inference, (0.7ms) NMS
# 21 D00s, 49 D10s, Done. (138.8ms) Inference, (0.8ms) NMS
# Done. (139.5ms) Inference, (0.2ms) NMS
# 76 D00s, Done. (135.7ms) Inference, (0.8ms) NMS
# 283 D00s, 17 D10s, Done. (139.8ms) Inference, (0.8ms) NMS
# 85 D00s, Done. (139.4ms) Inference, (0.8ms) NMS
# 268 D00s, 32 D10s, Done. (141.1ms) Inference, (0.8ms) NMS
# 1 D10, 14 D40s, Done. (138.2ms) Inference, (0.8ms) NMS
# 1 D10, 9 D40s, Done. (139.7ms) Inference, (0.8ms) NMS
# 4 D20s, 3 D40s, Done. (133.5ms) Inference, (0.7ms) NMS
# 56 D00s, Done. (135.7ms) Inference, (0.7ms) NMS
# Done. (142.9ms) Inference, (0.2ms) NMS
# 2 D00s, Done. (145.2ms) Inference, (0.9ms) NMS
# Done. (140.0ms) Inference, (0.2ms) NMS
# 5 D00s, Done. (137.8ms) Inference, (0.7ms) NMS
# 29 D10s, Done. (142.1ms) Inference, (0.9ms) NMS
# Done. (138.9ms) Inference, (0.2ms) NMS
# 17 D00s, 60 D10s, Done. (138.1ms) Inference, (0.8ms) NMS
# 8 D00s, Done. (139.8ms) Inference, (0.8ms) NMS
# 103 D00s, 3 D10s, 14 D40s, Done. (138.2ms) Inference, (0.7ms) NMS
# 5 D10s, Done. (137.5ms) Inference, (0.7ms) NMS
# 181 D00s, 17 D20s, Done. (138.6ms) Inference, (0.8ms) NMS
# Done. (139.6ms) Inference, (0.2ms) NMS
# Done. (140.2ms) Inference, (0.2ms) NMS
# 58 D00s, 28 D10s, Done. (136.6ms) Inference, (0.8ms) NMS
# Done. (140.2ms) Inference, (0.2ms) NMS
# 29 D00s, 39 D10s, Done. (138.5ms) Inference, (0.7ms) NMS
# 107 D00s, Done. (140.7ms) Inference, (0.8ms) NMS
# Done. (141.0ms) Inference, (0.2ms) NMS
# Done. (137.8ms) Inference, (0.2ms) NMS
# 6 D10s, Done. (143.8ms) Inference, (0.8ms) NMS
# 17 D00s, Done. (136.3ms) Inference, (0.8ms) NMS
# 8 D40s, Done. (139.7ms) Inference, (0.8ms) NMS
# Done. (137.0ms) Inference, (0.1ms) NMS
# 67 D00s, Done. (137.8ms) Inference, (0.7ms) NMS
# 6 D00s, Done. (139.8ms) Inference, (0.8ms) NMS
# 280 D00s, 20 D10s, Done. (136.1ms) Inference, (0.8ms) NMS
# 286 D00s, 8 D10s, 6 D40s, Done. (138.5ms) Inference, (0.8ms) NMS
# 97 D00s, 1 D40, Done. (140.9ms) Inference, (0.9ms) NMS
# Done. (143.9ms) Inference, (0.2ms) NMS
# 203 D00s, 97 D20s, Done. (139.9ms) Inference, (0.9ms) NMS
# 6 D00s, 6 D10s, Done. (144.9ms) Inference, (0.8ms) NMS
# 7 D00s, Done. (144.3ms) Inference, (0.8ms) NMS
# 300 D00s, Done. (141.1ms) Inference, (0.8ms) NMS
# Done. (136.4ms) Inference, (0.2ms) NMS
# Done. (136.5ms) Inference, (0.2ms) NMS
# 45 D00s, 12 D40s, Done. (138.1ms) Inference, (0.8ms) NMS
# 6 D00s, Done. (140.8ms) Inference, (0.8ms) NMS
# 19 D00s, Done. (141.1ms) Inference, (0.8ms) NMS
# 14 D00s, Done. (141.1ms) Inference, (0.7ms) NMS
# 3 D00s, Done. (140.7ms) Inference, (0.8ms) NMS
# Done. (140.0ms) Inference, (0.2ms) NMS
# 127 D00s, 2 D10s, Done. (137.7ms) Inference, (0.8ms) NMS
# Done. (137.8ms) Inference, (0.5ms) NMS
# 38 D40s, Done. (141.7ms) Inference, (0.8ms) NMS
# 300 D00s, Done. (136.2ms) Inference, (0.8ms) NMS
# 106 D00s, Done. (139.8ms) Inference, (0.8ms) NMS
# 79 D00s, Done. (140.5ms) Inference, (0.8ms) NMS
# Done. (143.2ms) Inference, (0.5ms) NMS
# 221 D00s, 79 D20s, Done. (136.6ms) Inference, (0.8ms) NMS
# 4 D00s, Done. (135.7ms) Inference, (0.8ms) NMS
# 89 D00s, Done. (136.1ms) Inference, (0.7ms) NMS
# 81 D00s, Done. (139.6ms) Inference, (0.8ms) NMS
# 300 D00s, Done. (141.7ms) Inference, (0.8ms) NMS
# 300 D00s, Done. (141.2ms) Inference, (0.8ms) NMS
# 153 D00s, 9 D20s, Done. (138.6ms) Inference, (0.7ms) NMS
# 97 D00s, Done. (138.1ms) Inference, (0.8ms) NMS
# 89 D00s, Done. (140.5ms) Inference, (0.9ms) NMS
# 281 D00s, 19 D10s, Done. (136.7ms) Inference, (0.8ms) NMS
# 58 D00s, 21 D10s, 10 D40s, Done. (137.5ms) Inference, (0.8ms) NMS
# 2 D40s, Done. (139.2ms) Inference, (0.8ms) NMS
# 132 D00s, 73 D10s, Done. (139.2ms) Inference, (0.8ms) NMS
# 132 D00s, Done. (139.7ms) Inference, (0.8ms) NMS
# 204 D00s, 20 D10s, 60 D20s, 16 D40s, Done. (139.5ms) Inference, (0.8ms) NMS
# Done. (140.5ms) Inference, (0.2ms) NMS
# Done. (141.5ms) Inference, (0.2ms) NMS
# 68 D00s, 1 D10, Done. (137.6ms) Inference, (0.7ms) NMS
# 7 D10s, 19 D40s, Done. (136.0ms) Inference, (0.8ms) NMS
# 140 D00s, 1 D40, Done. (139.0ms) Inference, (0.8ms) NMS
# 93 D00s, Done. (138.8ms) Inference, (0.8ms) NMS
# 82 D00s, Done. (136.5ms) Inference, (0.8ms) NMS
# Done. (137.8ms) Inference, (0.2ms) NMS
# Done. (134.6ms) Inference, (0.1ms) NMS
# Done. (139.6ms) Inference, (0.2ms) NMS
# 7 D00s, 1 D20, Done. (136.8ms) Inference, (0.8ms) NMS
# Done. (140.2ms) Inference, (0.2ms) NMS
# 207 D40s, Done. (141.1ms) Inference, (0.8ms) NMS
# 20 D00s, Done. (142.6ms) Inference, (0.9ms) NMS
# 3 D00s, Done. (137.2ms) Inference, (0.7ms) NMS
# Done. (137.2ms) Inference, (0.1ms) NMS
# 239 D00s, 17 D40s, Done. (141.1ms) Inference, (0.8ms) NMS
# 1 D10, 8 D40s, Done. (139.7ms) Inference, (0.8ms) NMS
# 27 D00s, Done. (140.4ms) Inference, (0.8ms) NMS
# 289 D00s, 11 D10s, Done. (139.3ms) Inference, (0.8ms) NMS
# 69 D00s, Done. (142.4ms) Inference, (0.8ms) NMS
# 23 D00s, 133 D10s, Done. (148.3ms) Inference, (0.8ms) NMS
# 228 D00s, Done. (138.8ms) Inference, (0.8ms) NMS
# 18 D00s, Done. (138.1ms) Inference, (0.7ms) NMS
# Done. (137.0ms) Inference, (0.1ms) NMS
# Done. (137.4ms) Inference, (0.1ms) NMS
# Done. (135.4ms) Inference, (0.1ms) NMS
# Done. (139.2ms) Inference, (0.2ms) NMS
# 124 D00s, Done. (136.1ms) Inference, (0.8ms) NMS
# 6 D00s, Done. (136.0ms) Inference, (0.7ms) NMS
# 66 D00s, Done. (137.9ms) Inference, (0.7ms) NMS
# 110 D00s, Done. (138.9ms) Inference, (0.8ms) NMS
# 139 D00s, 43 D10s, Done. (140.5ms) Inference, (0.9ms) NMS
# 65 D00s, Done. (139.6ms) Inference, (0.8ms) NMS
# 42 D20s, 11 D40s, Done. (138.7ms) Inference, (0.8ms) NMS
# Done. (140.9ms) Inference, (0.1ms) NMS
# 184 D00s, Done. (138.4ms) Inference, (0.8ms) NMS
# 116 D00s, 1 D10, Done. (139.3ms) Inference, (0.8ms) NMS
# 3 D00s, 3 D20s, Done. (140.0ms) Inference, (0.8ms) NMS
# 38 D00s, 11 D10s, Done. (135.8ms) Inference, (0.7ms) NMS
# 2 D00s, 4 D10s, Done. (138.6ms) Inference, (0.8ms) NMS
# Done. (136.0ms) Inference, (0.1ms) NMS
# 18 D00s, Done. (140.3ms) Inference, (0.8ms) NMS
# 14 D00s, 14 D10s, 18 D20s, Done. (138.1ms) Inference, (0.8ms) NMS
# Done. (139.9ms) Inference, (0.2ms) NMS
# 35 D00s, Done. (141.2ms) Inference, (0.8ms) NMS
# 285 D00s, Done. (141.9ms) Inference, (0.8ms) NMS
# Done. (139.6ms) Inference, (0.1ms) NMS
# Done. (139.2ms) Inference, (0.2ms) NMS
# 101 D00s, 4 D10s, Done. (137.8ms) Inference, (0.9ms) NMS
# Done. (138.8ms) Inference, (0.2ms) NMS
# Done. (139.3ms) Inference, (0.6ms) NMS
# 3 D00s, Done. (136.1ms) Inference, (0.8ms) NMS
# Done. (138.7ms) Inference, (0.1ms) NMS
# Done. (138.3ms) Inference, (0.2ms) NMS
# 1 D00, Done. (140.2ms) Inference, (0.8ms) NMS
# Done. (137.7ms) Inference, (0.2ms) NMS
# 154 D00s, 10 D40s, Done. (139.9ms) Inference, (0.8ms) NMS
# 220 D00s, 4 D10s, Done. (140.8ms) Inference, (0.8ms) NMS
# 46 D00s, Done. (138.5ms) Inference, (0.7ms) NMS
# 300 D00s, Done. (138.7ms) Inference, (0.8ms) NMS
# Done. (141.2ms) Inference, (0.2ms) NMS
# 3 D00s, Done. (140.2ms) Inference, (0.8ms) NMS
# 98 D00s, Done. (141.2ms) Inference, (0.8ms) NMS
# 72 D00s, 28 D10s, Done. (143.8ms) Inference, (0.9ms) NMS
# 2 D00s, Done. (137.6ms) Inference, (0.8ms) NMS
# Done. (137.9ms) Inference, (0.1ms) NMS
# 73 D00s, Done. (138.6ms) Inference, (0.8ms) NMS
# Done. (140.4ms) Inference, (0.2ms) NMS
# 7 D00s, 1 D10, Done. (136.1ms) Inference, (0.8ms) NMS
# 198 D00s, 21 D10s, Done. (139.5ms) Inference, (0.8ms) NMS
# 15 D00s, Done. (139.0ms) Inference, (0.8ms) NMS
# Done. (143.0ms) Inference, (0.2ms) NMS
# 48 D00s, 91 D10s, 44 D20s, Done. (137.5ms) Inference, (0.8ms) NMS
# 34 D00s, Done. (141.2ms) Inference, (0.8ms) NMS
# 167 D00s, Done. (140.8ms) Inference, (0.8ms) NMS
# 31 D10s, Done. (141.8ms) Inference, (0.8ms) NMS
# 148 D00s, Done. (141.0ms) Inference, (0.8ms) NMS
# Done. (137.3ms) Inference, (0.2ms) NMS
# 178 D00s, 35 D10s, Done. (143.2ms) Inference, (0.9ms) NMS
# Done. (140.2ms) Inference, (0.2ms) NMS
# 88 D00s, Done. (136.7ms) Inference, (0.8ms) NMS
# 1 D10, Done. (139.0ms) Inference, (0.8ms) NMS
# 2 D40s, Done. (139.7ms) Inference, (0.7ms) NMS
# 47 D10s, Done. (138.5ms) Inference, (0.8ms) NMS
# 107 D00s, 9 D40s, Done. (138.5ms) Inference, (0.8ms) NMS
# 295 D00s, 5 D20s, Done. (141.8ms) Inference, (0.8ms) NMS
# Done. (138.4ms) Inference, (0.2ms) NMS
# 57 D00s, Done. (139.0ms) Inference, (0.8ms) NMS
# Done. (139.3ms) Inference, (0.2ms) NMS
# 210 D00s, 35 D10s, Done. (140.0ms) Inference, (0.8ms) NMS
# 2 D10s, Done. (138.3ms) Inference, (0.7ms) NMS
# 151 D00s, 6 D10s, 17 D20s, 2 D40s, Done. (136.7ms) Inference, (0.7ms) NMS
# 12 D40s, Done. (136.8ms) Inference, (0.7ms) NMS
# 61 D00s, Done. (137.0ms) Inference, (0.8ms) NMS
# 2 D00s, 86 D10s, Done. (140.7ms) Inference, (0.8ms) NMS
# Done. (139.3ms) Inference, (0.2ms) NMS
# 295 D00s, 5 D10s, Done. (140.1ms) Inference, (1.1ms) NMS
# 132 D00s, Done. (139.9ms) Inference, (0.8ms) NMS
# Done. (143.4ms) Inference, (0.2ms) NMS
# 50 D00s, Done. (138.0ms) Inference, (0.9ms) NMS
# 140 D00s, Done. (136.0ms) Inference, (0.8ms) NMS
# 17 D00s, 6 D40s, Done. (139.3ms) Inference, (0.8ms) NMS
# 117 D00s, 1 D10, 2 D40s, Done. (138.4ms) Inference, (0.8ms) NMS
# 99 D00s, Done. (140.4ms) Inference, (0.8ms) NMS
# 225 D00s, Done. (139.9ms) Inference, (0.8ms) NMS
# 110 D00s, 34 D10s, 59 D20s, 97 D40s, Done. (137.4ms) Inference, (0.8ms) NMS
# 30 D00s, 59 D10s, 94 D40s, Done. (138.1ms) Inference, (0.8ms) NMS
# Done. (139.2ms) Inference, (0.2ms) NMS
# 12 D10s, Done. (141.5ms) Inference, (0.8ms) NMS
# 18 D10s, Done. (136.4ms) Inference, (0.8ms) NMS
# 5 D10s, Done. (142.8ms) Inference, (0.9ms) NMS
# Done. (139.4ms) Inference, (0.2ms) NMS
# Done. (141.4ms) Inference, (0.2ms) NMS
# 2 D10s, 2 D20s, Done. (137.7ms) Inference, (0.8ms) NMS
# Done. (137.4ms) Inference, (0.1ms) NMS
# 124 D00s, Done. (140.9ms) Inference, (0.8ms) NMS
# 10 D00s, Done. (135.7ms) Inference, (0.7ms) NMS
# Done. (135.4ms) Inference, (0.2ms) NMS
# 41 D00s, Done. (139.9ms) Inference, (0.8ms) NMS
# 76 D00s, Done. (138.5ms) Inference, (0.8ms) NMS
# 167 D00s, 23 D10s, 13 D40s, Done. (139.5ms) Inference, (0.8ms) NMS
# Done. (138.5ms) Inference, (0.2ms) NMS
# 282 D00s, 18 D10s, Done. (142.1ms) Inference, (0.8ms) NMS
# 92 D00s, 3 D10s, 192 D20s, 1 D40, Done. (134.2ms) Inference, (0.8ms) NMS
# 27 D00s, Done. (138.0ms) Inference, (0.8ms) NMS
# 184 D00s, 84 D40s, Done. (139.3ms) Inference, (0.8ms) NMS
# 22 D00s, Done. (142.5ms) Inference, (0.8ms) NMS
# 5 D00s, Done. (138.1ms) Inference, (0.8ms) NMS
# 202 D00s, Done. (135.8ms) Inference, (0.7ms) NMS
# Done. (139.5ms) Inference, (0.2ms) NMS
# 119 D00s, Done. (135.8ms) Inference, (0.7ms) NMS
# Done. (140.4ms) Inference, (0.2ms) NMS
# 260 D00s, Done. (138.5ms) Inference, (0.8ms) NMS
# 100 D00s, 6 D10s, Done. (139.0ms) Inference, (0.9ms) NMS
# 300 D00s, Done. (140.7ms) Inference, (0.9ms) NMS
# 73 D00s, 31 D10s, Done. (139.9ms) Inference, (0.8ms) NMS
# 1 D00, Done. (140.7ms) Inference, (0.8ms) NMS
# 81 D00s, Done. (141.4ms) Inference, (0.8ms) NMS
# 170 D00s, 3 D10s, 14 D40s, Done. (140.4ms) Inference, (0.8ms) NMS
# Done. (140.9ms) Inference, (0.2ms) NMS
# Done. (138.2ms) Inference, (0.2ms) NMS
# 29 D00s, Done. (136.3ms) Inference, (0.8ms) NMS
# 92 D00s, 13 D10s, 7 D40s, Done. (138.6ms) Inference, (0.8ms) NMS
# Done. (139.5ms) Inference, (0.1ms) NMS
# 89 D00s, 1 D40, Done. (140.9ms) Inference, (0.8ms) NMS
# 66 D00s, 4 D10s, 58 D40s, Done. (139.9ms) Inference, (0.8ms) NMS
# 300 D00s, Done. (138.5ms) Inference, (0.8ms) NMS
# 241 D00s, 59 D10s, Done. (138.9ms) Inference, (0.8ms) NMS
# 153 D00s, Done. (139.8ms) Inference, (0.8ms) NMS
# 283 D00s, 17 D10s, Done. (139.6ms) Inference, (0.8ms) NMS
# 278 D00s, 22 D10s, Done. (141.9ms) Inference, (0.9ms) NMS
# 42 D00s, 69 D10s, Done. (138.5ms) Inference, (0.7ms) NMS
# Done. (137.6ms) Inference, (0.2ms) NMS
# Done. (138.4ms) Inference, (0.2ms) NMS
# 21 D00s, Done. (134.7ms) Inference, (0.7ms) NMS
# Done. (136.4ms) Inference, (0.2ms) NMS
# 6 D40s, Done. (139.1ms) Inference, (0.8ms) NMS
# Done. (134.5ms) Inference, (0.1ms) NMS
# 29 D00s, Done. (138.5ms) Inference, (0.8ms) NMS
# 279 D00s, 6 D10s, Done. (136.5ms) Inference, (0.8ms) NMS
# 131 D00s, Done. (141.4ms) Inference, (0.9ms) NMS
# 44 D10s, Done. (136.0ms) Inference, (0.7ms) NMS
# 28 D00s, Done. (134.8ms) Inference, (0.7ms) NMS
# 129 D00s, Done. (137.3ms) Inference, (0.8ms) NMS
# 300 D00s, Done. (140.2ms) Inference, (0.9ms) NMS
# 6 D10s, 5 D40s, Done. (141.5ms) Inference, (0.8ms) NMS
# 116 D00s, 38 D10s, Done. (139.1ms) Inference, (0.7ms) NMS
# 17 D00s, Done. (139.6ms) Inference, (0.8ms) NMS
# Done. (138.9ms) Inference, (0.2ms) NMS
# Done. (137.7ms) Inference, (0.2ms) NMS
# 110 D00s, Done. (135.9ms) Inference, (0.8ms) NMS
# Done. (139.9ms) Inference, (0.2ms) NMS
# Done. (140.0ms) Inference, (0.2ms) NMS
# Done. (139.3ms) Inference, (0.2ms) NMS
# 125 D00s, Done. (139.8ms) Inference, (0.8ms) NMS
# Done. (137.8ms) Inference, (0.2ms) NMS
# 300 D00s, Done. (134.8ms) Inference, (1.0ms) NMS
# 26 D00s, Done. (141.7ms) Inference, (0.8ms) NMS
# Done. (138.8ms) Inference, (0.2ms) NMS
# Done. (138.9ms) Inference, (0.2ms) NMS
# 274 D00s, 26 D10s, Done. (142.9ms) Inference, (1.2ms) NMS
# 60 D00s, Done. (142.3ms) Inference, (0.9ms) NMS
# 79 D00s, 25 D10s, Done. (140.1ms) Inference, (0.8ms) NMS
# 101 D00s, 11 D10s, 6 D40s, Done. (141.1ms) Inference, (0.8ms) NMS
# Done. (140.4ms) Inference, (0.2ms) NMS
# 83 D00s, Done. (137.3ms) Inference, (0.7ms) NMS
# 285 D00s, 15 D10s, Done. (140.7ms) Inference, (1.0ms) NMS
# 109 D00s, 6 D10s, Done. (140.0ms) Inference, (0.8ms) NMS
# 35 D00s, Done. (137.8ms) Inference, (0.7ms) NMS
# Done. (139.7ms) Inference, (0.2ms) NMS
# 244 D00s, 56 D10s, Done. (137.4ms) Inference, (0.8ms) NMS
# Done. (138.4ms) Inference, (0.2ms) NMS
# 90 D40s, Done. (140.1ms) Inference, (0.8ms) NMS
# 24 D00s, 6 D10s, 75 D40s, Done. (137.2ms) Inference, (0.8ms) NMS
# Done. (140.3ms) Inference, (0.2ms) NMS
# 3 D10s, 6 D40s, Done. (140.2ms) Inference, (0.9ms) NMS
# Done. (140.1ms) Inference, (0.2ms) NMS
# 218 D00s, 1 D10, 81 D20s, Done. (138.6ms) Inference, (0.8ms) NMS
# 95 D00s, Done. (137.2ms) Inference, (0.8ms) NMS
# Done. (140.0ms) Inference, (0.2ms) NMS
# 5 D00s, 6 D40s, Done. (136.2ms) Inference, (0.7ms) NMS
# 243 D00s, 57 D20s, Done. (136.4ms) Inference, (0.9ms) NMS
# 34 D00s, 2 D10s, Done. (139.8ms) Inference, (0.8ms) NMS
# Done. (137.6ms) Inference, (0.1ms) NMS
# 14 D00s, 3 D10s, Done. (137.1ms) Inference, (0.8ms) NMS
# Done. (140.0ms) Inference, (0.2ms) NMS
# 13 D00s, Done. (141.1ms) Inference, (0.8ms) NMS
# 238 D00s, 62 D10s, Done. (136.7ms) Inference, (0.8ms) NMS
# 13 D10s, 10 D40s, Done. (139.0ms) Inference, (0.7ms) NMS
# 5 D00s, Done. (138.1ms) Inference, (0.7ms) NMS
# 7 D10s, Done. (137.1ms) Inference, (0.7ms) NMS
# 278 D00s, 22 D40s, Done. (138.5ms) Inference, (0.8ms) NMS
# 7 D00s, Done. (141.8ms) Inference, (0.8ms) NMS
# Done. (143.6ms) Inference, (0.2ms) NMS
# 73 D00s, Done. (136.7ms) Inference, (0.8ms) NMS
# 86 D00s, 19 D20s, Done. (139.3ms) Inference, (0.9ms) NMS
# 31 D10s, 24 D40s, Done. (140.9ms) Inference, (0.8ms) NMS
# 89 D00s, 35 D40s, Done. (139.7ms) Inference, (0.8ms) NMS
# 43 D20s, Done. (134.6ms) Inference, (0.7ms) NMS
# Done. (135.7ms) Inference, (0.2ms) NMS
# 6 D00s, Done. (138.5ms) Inference, (0.8ms) NMS
# 53 D00s, 24 D10s, Done. (136.8ms) Inference, (0.7ms) NMS
# 150 D00s, Done. (140.5ms) Inference, (0.9ms) NMS
# 41 D00s, Done. (140.3ms) Inference, (0.8ms) NMS
# 14 D00s, Done. (140.2ms) Inference, (0.9ms) NMS
# 27 D00s, 147 D10s, 3 D40s, Done. (137.3ms) Inference, (0.7ms) NMS
# 300 D00s, Done. (142.0ms) Inference, (0.8ms) NMS
# Done. (136.5ms) Inference, (0.1ms) NMS
# Done. (139.9ms) Inference, (0.2ms) NMS
# 1 D00, Done. (138.0ms) Inference, (0.8ms) NMS
# Done. (139.4ms) Inference, (0.2ms) NMS
# Done. (141.0ms) Inference, (0.2ms) NMS
# 21 D00s, 30 D10s, Done. (138.6ms) Inference, (0.8ms) NMS
# 42 D40s, Done. (135.7ms) Inference, (0.7ms) NMS
# Done. (140.3ms) Inference, (0.2ms) NMS
# 298 D00s, 2 D10s, Done. (140.1ms) Inference, (0.8ms) NMS
# 235 D00s, Done. (139.1ms) Inference, (0.7ms) NMS
# 9 D00s, 3 D40s, Done. (141.9ms) Inference, (0.8ms) NMS
# 37 D00s, Done. (141.0ms) Inference, (0.8ms) NMS
# 38 D00s, 11 D10s, Done. (135.8ms) Inference, (0.8ms) NMS
# 12 D00s, Done. (136.2ms) Inference, (0.8ms) NMS
# 235 D00s, 64 D10s, 1 D40, Done. (137.4ms) Inference, (0.8ms) NMS
# 67 D00s, 80 D20s, Done. (138.6ms) Inference, (0.8ms) NMS
# 7 D00s, Done. (139.4ms) Inference, (0.8ms) NMS
# 8 D00s, Done. (141.3ms) Inference, (0.9ms) NMS
# 103 D00s, Done. (139.9ms) Inference, (0.8ms) NMS
# 28 D10s, Done. (139.7ms) Inference, (0.8ms) NMS
# 120 D00s, 4 D10s, Done. (140.5ms) Inference, (0.8ms) NMS
# 82 D00s, Done. (141.5ms) Inference, (0.8ms) NMS
# 3 D00s, Done. (141.1ms) Inference, (0.8ms) NMS
# 13 D00s, 43 D10s, 20 D40s, Done. (140.7ms) Inference, (0.8ms) NMS
# 54 D00s, Done. (142.1ms) Inference, (0.8ms) NMS
# 36 D00s, 12 D10s, Done. (136.0ms) Inference, (0.7ms) NMS
# 83 D00s, Done. (138.4ms) Inference, (0.9ms) NMS
# 16 D20s, Done. (140.5ms) Inference, (0.8ms) NMS
# 4 D00s, 5 D10s, Done. (136.4ms) Inference, (0.7ms) NMS
# 257 D00s, 43 D10s, Done. (139.4ms) Inference, (0.8ms) NMS
# 22 D00s, Done. (140.3ms) Inference, (0.8ms) NMS
# Done. (136.8ms) Inference, (0.2ms) NMS
# 67 D10s, Done. (141.3ms) Inference, (0.8ms) NMS
# 80 D00s, Done. (140.5ms) Inference, (0.8ms) NMS
# 70 D00s, Done. (139.4ms) Inference, (0.8ms) NMS
# 11 D00s, Done. (140.5ms) Inference, (0.8ms) NMS
# 8 D00s, Done. (140.1ms) Inference, (0.8ms) NMS
# Done. (136.4ms) Inference, (0.2ms) NMS
# 169 D00s, 67 D20s, 14 D40s, Done. (138.3ms) Inference, (0.8ms) NMS
# Done. (141.0ms) Inference, (0.2ms) NMS
# 256 D00s, Done. (138.7ms) Inference, (0.8ms) NMS
# 39 D00s, Done. (141.3ms) Inference, (0.8ms) NMS
# Done. (141.0ms) Inference, (0.2ms) NMS
# 2 D00s, 1 D40, Done. (140.7ms) Inference, (0.8ms) NMS
# 8 D00s, Done. (139.6ms) Inference, (0.8ms) NMS
# Done. (136.3ms) Inference, (0.1ms) NMS
# 115 D00s, Done. (138.9ms) Inference, (0.8ms) NMS
# Done. (138.9ms) Inference, (0.2ms) NMS
# 296 D00s, Done. (138.3ms) Inference, (0.8ms) NMS
# 36 D00s, Done. (140.6ms) Inference, (0.8ms) NMS
# ...
# Done. (142.2ms) Inference, (0.2ms) NMS
# 7 D00s, Done. (140.3ms) Inference, (0.8ms) NMS
# 300 D00s, Done. (144.4ms) Inference, (0.9ms) NMS
# Done. (145.5ms) Inference, (0.2ms) NMS
# 98 D00s, 76 D10s, Done. (142.3ms) Inference, (0.8ms) NMS
# 300 D00s, Done. (139.4ms) Inference, (0.8ms) NMS
# 201 D00s, 2 D10s, Done. (135.4ms) Inference, (0.8ms) NMS
# 22 D00s, Done. (140.6ms) Inference, (0.8ms) NMS
# 6 D10s, Done. (142.2ms) Inference, (0.8ms) NMS
# 283 D00s, 17 D10s, Done. (140.3ms) Inference, (0.9ms) NMS
# 121 D00s, Done. (141.9ms) Inference, (0.8ms) NMS
# Done. (139.2ms) Inference, (0.5ms) NMS
# 5 D00s, Done. (137.4ms) Inference, (0.8ms) NMS
# 128 D00s, 7 D10s, 165 D20s, Done. (138.9ms) Inference, (0.9ms) NMS
# 15 D10s, Done. (140.0ms) Inference, (0.8ms) NMS
# 1 D00, Done. (134.8ms) Inference, (0.8ms) NMS
# 255 D00s, 45 D20s, Done. (142.1ms) Inference, (0.8ms) NMS
# 4 D00s, Done. (141.5ms) Inference, (0.8ms) NMS
# 200 D00s, Done. (139.7ms) Inference, (0.8ms) NMS
# 7 D00s, Done. (141.8ms) Inference, (0.8ms) NMS
# Done. (136.1ms) Inference, (0.2ms) NMS
# 300 D00s, Done. (140.4ms) Inference, (0.8ms) NMS
# 63 D00s, Done. (140.6ms) Inference, (0.7ms) NMS
# 131 D00s, Done. (140.9ms) Inference, (0.8ms) NMS
# Done. (141.3ms) Inference, (0.2ms) NMS
# 4 D00s, 67 D10s, Done. (139.8ms) Inference, (0.8ms) NMS
# 19 D00s, Done. (139.8ms) Inference, (0.7ms) NMS
# 127 D00s, Done. (142.8ms) Inference, (0.8ms) NMS
# 91 D00s, Done. (137.7ms) Inference, (0.7ms) NMS
# 163 D10s, Done. (140.6ms) Inference, (0.8ms) NMS
# 119 D00s, 2 D40s, Done. (139.1ms) Inference, (0.8ms) NMS
# 300 D00s, Done. (136.8ms) Inference, (0.8ms) NMS
# 133 D00s, 13 D10s, 9 D40s, Done. (138.7ms) Inference, (0.8ms) NMS
# 253 D00s, 47 D10s, Done. (141.4ms) Inference, (0.9ms) NMS
# 113 D00s, 105 D20s, Done. (137.3ms) Inference, (0.8ms) NMS
# 24 D00s, 8 D10s, Done. (142.1ms) Inference, (0.8ms) NMS
# 63 D00s, 9 D20s, Done. (137.3ms) Inference, (0.8ms) NMS
# 226 D00s, Done. (140.6ms) Inference, (0.8ms) NMS
# 68 D00s, 25 D10s, Done. (136.2ms) Inference, (0.8ms) NMS
# 205 D00s, 10 D10s, 85 D20s, Done. (140.0ms) Inference, (0.8ms) NMS
# Done. (142.9ms) Inference, (0.2ms) NMS
# 93 D00s, Done. (139.8ms) Inference, (0.8ms) NMS
# 2 D00s, 7 D10s, Done. (139.1ms) Inference, (0.8ms) NMS
# 300 D00s, Done. (139.2ms) Inference, (0.9ms) NMS
# Done. (138.9ms) Inference, (0.2ms) NMS
# 293 D00s, 1 D10, Done. (140.5ms) Inference, (0.9ms) NMS
# Done. (142.6ms) Inference, (0.2ms) NMS
# 66 D00s, Done. (138.6ms) Inference, (0.8ms) NMS
# 16 D00s, Done. (138.4ms) Inference, (0.7ms) NMS
# Done. (138.3ms) Inference, (0.2ms) NMS
# 69 D00s, Done. (137.9ms) Inference, (0.8ms) NMS
# 211 D00s, 28 D10s, 61 D40s, Done. (142.3ms) Inference, (0.9ms) NMS
# Done. (144.5ms) Inference, (0.2ms) NMS
# 109 D00s, Done. (139.2ms) Inference, (0.9ms) NMS
# Done. (139.7ms) Inference, (0.2ms) NMS
# 182 D00s, 9 D20s, 68 D40s, Done. (139.7ms) Inference, (0.8ms) NMS
# 292 D00s, Done. (140.6ms) Inference, (0.8ms) NMS
# 134 D00s, Done. (140.2ms) Inference, (0.8ms) NMS
# 265 D00s, 35 D10s, Done. (137.6ms) Inference, (0.8ms) NMS
# 130 D00s, Done. (139.5ms) Inference, (0.8ms) NMS
# Done. (142.2ms) Inference, (0.2ms) NMS
# 72 D00s, Done. (138.8ms) Inference, (0.8ms) NMS
# 100 D00s, Done. (138.4ms) Inference, (0.8ms) NMS
# Done. (140.1ms) Inference, (0.2ms) NMS
# 1 D00, 20 D10s, Done. (139.2ms) Inference, (0.8ms) NMS
# 51 D40s, Done. (137.9ms) Inference, (0.7ms) NMS
# 1 D00, Done. (138.3ms) Inference, (0.8ms) NMS
# 300 D00s, Done. (140.9ms) Inference, (0.9ms) NMS
# 229 D00s, Done. (138.0ms) Inference, (0.8ms) NMS
# Done. (141.8ms) Inference, (0.2ms) NMS
# 92 D00s, Done. (138.6ms) Inference, (0.8ms) NMS
# Done. (140.3ms) Inference, (0.2ms) NMS
# 151 D00s, Done. (140.5ms) Inference, (0.9ms) NMS
# 67 D00s, 3 D10s, Done. (143.3ms) Inference, (0.8ms) NMS
# 87 D00s, Done. (140.0ms) Inference, (0.8ms) NMS
# 20 D00s, 5 D40s, Done. (143.6ms) Inference, (0.8ms) NMS
# 186 D00s, 75 D20s, Done. (137.5ms) Inference, (0.7ms) NMS
# 136 D00s, 1 D10, Done. (140.8ms) Inference, (0.9ms) NMS
# Done. (137.9ms) Inference, (0.2ms) NMS
# 113 D00s, 37 D10s, Done. (139.3ms) Inference, (0.7ms) NMS
# 52 D00s, Done. (139.3ms) Inference, (0.8ms) NMS
# 4 D40s, Done. (137.6ms) Inference, (0.7ms) NMS
# 84 D00s, Done. (138.6ms) Inference, (0.8ms) NMS
# 73 D00s, Done. (138.2ms) Inference, (0.8ms) NMS
# 243 D00s, 57 D10s, Done. (140.4ms) Inference, (0.8ms) NMS
# 1 D20, Done. (138.5ms) Inference, (0.7ms) NMS
# 119 D00s, 60 D10s, Done. (136.4ms) Inference, (0.7ms) NMS
# 13 D00s, 15 D10s, Done. (141.0ms) Inference, (0.8ms) NMS
# 100 D00s, 38 D10s, Done. (138.4ms) Inference, (0.8ms) NMS
# 172 D00s, 128 D20s, Done. (139.2ms) Inference, (0.9ms) NMS
# Done. (141.7ms) Inference, (0.2ms) NMS
# 13 D00s, 3 D10s, 28 D20s, Done. (138.6ms) Inference, (0.8ms) NMS
# 226 D00s, 29 D10s, 45 D40s, Done. (142.7ms) Inference, (0.9ms) NMS
# Done. (144.1ms) Inference, (0.2ms) NMS
# 12 D00s, Done. (142.3ms) Inference, (0.8ms) NMS
# 1 D00, Done. (139.9ms) Inference, (0.8ms) NMS
# 93 D00s, 13 D10s, Done. (137.1ms) Inference, (0.8ms) NMS
# 7 D00s, Done. (142.0ms) Inference, (0.9ms) NMS
# Done. (144.1ms) Inference, (0.2ms) NMS
# 17 D00s, Done. (142.7ms) Inference, (0.8ms) NMS
# 139 D00s, 50 D20s, 3 D40s, Done. (140.6ms) Inference, (0.8ms) NMS
# Done. (140.2ms) Inference, (0.2ms) NMS
# 268 D00s, 6 D10s, Done. (138.3ms) Inference, (0.8ms) NMS
# Done. (139.9ms) Inference, (0.2ms) NMS
# 7 D00s, 1 D40, Done. (141.0ms) Inference, (0.8ms) NMS
# 25 D00s, 2 D10s, 3 D40s, Done. (138.4ms) Inference, (0.8ms) NMS
# 279 D00s, 21 D20s, Done. (142.8ms) Inference, (0.8ms) NMS
# 136 D00s, Done. (140.4ms) Inference, (0.8ms) NMS
# 96 D00s, Done. (142.0ms) Inference, (0.8ms) NMS
# 9 D00s, Done. (138.4ms) Inference, (0.8ms) NMS
# 164 D00s, Done. (139.1ms) Inference, (0.8ms) NMS
# 16 D40s, Done. (138.8ms) Inference, (0.8ms) NMS
# Done. (139.0ms) Inference, (0.2ms) NMS
# 18 D00s, Done. (138.0ms) Inference, (0.7ms) NMS
# Done. (138.2ms) Inference, (0.2ms) NMS
# Done. (141.6ms) Inference, (0.2ms) NMS
# Done. (137.9ms) Inference, (0.1ms) NMS
# 27 D00s, 3 D10s, Done. (134.2ms) Inference, (0.7ms) NMS
# Done. (138.0ms) Inference, (0.1ms) NMS
# Done. (136.1ms) Inference, (0.1ms) NMS
# 287 D00s, 13 D10s, Done. (139.8ms) Inference, (0.8ms) NMS
# 7 D00s, Done. (136.3ms) Inference, (0.7ms) NMS
# 4 D00s, Done. (138.7ms) Inference, (0.8ms) NMS
# 2 D00s, Done. (137.3ms) Inference, (0.8ms) NMS
# 10 D40s, Done. (142.7ms) Inference, (0.8ms) NMS
# 31 D00s, Done. (137.5ms) Inference, (0.7ms) NMS
# Done. (140.2ms) Inference, (0.2ms) NMS
# Done. (135.8ms) Inference, (0.2ms) NMS
# 30 D10s, Done. (138.3ms) Inference, (0.8ms) NMS
# Done. (136.2ms) Inference, (0.2ms) NMS
# 293 D00s, 7 D40s, Done. (136.7ms) Inference, (0.8ms) NMS
# Done. (141.9ms) Inference, (0.2ms) NMS
# Done. (139.5ms) Inference, (0.2ms) NMS
# 300 D00s, Done. (139.3ms) Inference, (0.8ms) NMS
# 2 D10s, Done. (143.0ms) Inference, (0.8ms) NMS
# 7 D00s, Done. (142.8ms) Inference, (0.8ms) NMS
# 22 D00s, Done. (144.1ms) Inference, (0.8ms) NMS
# Done. (139.8ms) Inference, (0.2ms) NMS
# Done. (138.1ms) Inference, (0.2ms) NMS
# 205 D00s, Done. (151.6ms) Inference, (0.9ms) NMS
# 7 D10s, Done. (141.5ms) Inference, (0.9ms) NMS
# Done. (140.4ms) Inference, (0.2ms) NMS
# Done. (139.6ms) Inference, (0.2ms) NMS
# 117 D00s, 8 D40s, Done. (140.2ms) Inference, (0.8ms) NMS
# 34 D00s, Done. (136.7ms) Inference, (0.7ms) NMS
# 85 D00s, Done. (137.6ms) Inference, (0.8ms) NMS
# Done. (141.7ms) Inference, (0.2ms) NMS
# Done. (142.0ms) Inference, (0.2ms) NMS
# 117 D00s, Done. (136.7ms) Inference, (0.8ms) NMS
# Done. (140.5ms) Inference, (0.2ms) NMS
# Done. (138.1ms) Inference, (0.2ms) NMS
# 103 D00s, Done. (140.4ms) Inference, (0.8ms) NMS
# 68 D00s, Done. (139.9ms) Inference, (0.8ms) NMS
# Done. (139.5ms) Inference, (0.2ms) NMS
# 158 D00s, 24 D10s, Done. (138.2ms) Inference, (0.8ms) NMS
# 6 D00s, Done. (134.2ms) Inference, (0.7ms) NMS
# 21 D00s, Done. (136.7ms) Inference, (0.8ms) NMS
# 296 D00s, 2 D40s, Done. (138.4ms) Inference, (0.8ms) NMS
# 95 D00s, 60 D40s, Done. (143.2ms) Inference, (0.8ms) NMS
# 3 D40s, Done. (137.9ms) Inference, (0.8ms) NMS
# Done. (139.3ms) Inference, (0.2ms) NMS
# 58 D00s, 59 D20s, Done. (139.7ms) Inference, (0.8ms) NMS
# 20 D00s, Done. (139.2ms) Inference, (0.7ms) NMS
# 189 D00s, Done. (137.5ms) Inference, (0.8ms) NMS
# 168 D00s, Done. (137.3ms) Inference, (0.8ms) NMS
# 300 D00s, Done. (139.6ms) Inference, (0.9ms) NMS
# 10 D00s, 5 D40s, Done. (140.8ms) Inference, (0.8ms) NMS
# Done. (138.1ms) Inference, (0.2ms) NMS
# 1 D00, Done. (139.1ms) Inference, (0.8ms) NMS
# 16 D00s, 15 D10s, 59 D20s, Done. (139.7ms) Inference, (0.8ms) NMS
# 65 D40s, Done. (142.2ms) Inference, (0.8ms) NMS
# 300 D00s, Done. (141.7ms) Inference, (0.9ms) NMS
# 5 D00s, Done. (139.1ms) Inference, (0.8ms) NMS
# Done. (136.7ms) Inference, (0.2ms) NMS
# 3 D00s, 3 D10s, Done. (140.5ms) Inference, (0.8ms) NMS
# 51 D00s, Done. (136.0ms) Inference, (0.7ms) NMS
# 79 D00s, Done. (140.8ms) Inference, (0.7ms) NMS
# 134 D00s, Done. (140.4ms) Inference, (0.8ms) NMS
# Done. (141.0ms) Inference, (0.2ms) NMS
# 38 D00s, Done. (138.8ms) Inference, (0.8ms) NMS
# Done. (140.8ms) Inference, (0.2ms) NMS
# 186 D00s, Done. (139.5ms) Inference, (0.8ms) NMS
# Done. (146.9ms) Inference, (0.2ms) NMS
# Done. (138.9ms) Inference, (0.2ms) NMS
# 148 D00s, Done. (138.0ms) Inference, (0.8ms) NMS
# 289 D00s, 11 D20s, Done. (137.9ms) Inference, (0.8ms) NMS
# 59 D00s, 60 D10s, Done. (135.2ms) Inference, (0.8ms) NMS
# 1 D00, 44 D10s, 255 D40s, Done. (138.5ms) Inference, (0.8ms) NMS
# 266 D00s, 22 D10s, 12 D20s, Done. (139.2ms) Inference, (0.9ms) NMS
# Done. (141.4ms) Inference, (0.2ms) NMS
# 31 D00s, Done. (139.4ms) Inference, (0.9ms) NMS
# Done. (137.6ms) Inference, (0.2ms) NMS
# 55 D40s, Done. (137.5ms) Inference, (0.8ms) NMS
# 3 D00s, Done. (134.7ms) Inference, (0.8ms) NMS
# Done. (132.8ms) Inference, (0.1ms) NMS
# 23 D00s, 1 D10, Done. (136.3ms) Inference, (0.8ms) NMS
# 272 D00s, Done. (137.6ms) Inference, (0.8ms) NMS
# 158 D00s, Done. (138.2ms) Inference, (0.8ms) NMS
# 300 D00s, Done. (139.7ms) Inference, (0.8ms) NMS
# 250 D00s, 1 D10, Done. (139.2ms) Inference, (0.8ms) NMS
# 114 D00s, Done. (137.8ms) Inference, (0.8ms) NMS
# Done. (142.8ms) Inference, (0.2ms) NMS
# Done. (138.5ms) Inference, (0.2ms) NMS
# Done. (136.1ms) Inference, (0.2ms) NMS
# 67 D00s, 18 D10s, Done. (139.0ms) Inference, (0.8ms) NMS
# Done. (141.1ms) Inference, (0.2ms) NMS
# 8 D00s, Done. (139.7ms) Inference, (0.8ms) NMS
# 55 D10s, Done. (140.6ms) Inference, (0.8ms) NMS
# 213 D00s, Done. (136.8ms) Inference, (0.8ms) NMS
# Done. (139.5ms) Inference, (0.2ms) NMS
# 16 D00s, Done. (136.8ms) Inference, (0.8ms) NMS
# Done. (137.0ms) Inference, (0.1ms) NMS
# 7 D00s, Done. (138.3ms) Inference, (0.8ms) NMS
# 117 D00s, Done. (139.5ms) Inference, (0.8ms) NMS
# 164 D00s, Done. (140.1ms) Inference, (0.8ms) NMS
# 145 D00s, 17 D40s, Done. (139.5ms) Inference, (0.8ms) NMS
# 228 D00s, 15 D10s, 3 D20s, Done. (139.6ms) Inference, (0.8ms) NMS
# 35 D00s, Done. (139.6ms) Inference, (0.8ms) NMS
# Done. (139.2ms) Inference, (0.2ms) NMS
# 91 D00s, Done. (135.9ms) Inference, (0.8ms) NMS
# 18 D00s, Done. (141.0ms) Inference, (0.8ms) NMS
# Done. (138.9ms) Inference, (0.1ms) NMS
# 113 D00s, Done. (138.4ms) Inference, (0.8ms) NMS
# Done. (139.2ms) Inference, (0.2ms) NMS
# Done. (138.0ms) Inference, (0.2ms) NMS
# 32 D10s, Done. (136.1ms) Inference, (0.8ms) NMS
# 58 D00s, 10 D40s, Done. (139.2ms) Inference, (0.8ms) NMS
# 125 D00s, Done. (137.5ms) Inference, (0.8ms) NMS
# 90 D40s, Done. (139.1ms) Inference, (0.8ms) NMS
# 125 D00s, 46 D10s, 129 D20s, Done. (143.4ms) Inference, (0.9ms) NMS
# Done. (138.5ms) Inference, (0.1ms) NMS
# Done. (136.1ms) Inference, (0.2ms) NMS
# 132 D00s, Done. (138.1ms) Inference, (0.8ms) NMS
# 13 D00s, 4 D20s, Done. (141.3ms) Inference, (0.8ms) NMS
# 29 D00s, 24 D10s, Done. (139.0ms) Inference, (0.8ms) NMS
# 23 D00s, Done. (139.2ms) Inference, (0.8ms) NMS
# 57 D00s, 1 D10, Done. (140.7ms) Inference, (0.8ms) NMS
# Done. (138.7ms) Inference, (0.2ms) NMS
# 263 D00s, Done. (136.3ms) Inference, (0.8ms) NMS
# 1 D00, Done. (139.0ms) Inference, (0.8ms) NMS
# 96 D00s, Done. (137.7ms) Inference, (0.7ms) NMS
# 300 D00s, Done. (140.7ms) Inference, (0.9ms) NMS
# 181 D00s, Done. (140.3ms) Inference, (0.8ms) NMS
# 3 D00s, Done. (137.6ms) Inference, (0.7ms) NMS
# 289 D00s, 11 D20s, Done. (135.6ms) Inference, (0.8ms) NMS
# 20 D00s, Done. (138.4ms) Inference, (0.8ms) NMS
# Done. (136.4ms) Inference, (0.1ms) NMS
# 196 D00s, Done. (139.7ms) Inference, (0.8ms) NMS
# 1 D00, 29 D10s, Done. (138.1ms) Inference, (0.8ms) NMS
# 186 D00s, 3 D10s, 111 D20s, Done. (138.5ms) Inference, (0.8ms) NMS
# 298 D00s, 2 D10s, Done. (139.8ms) Inference, (0.8ms) NMS
# 194 D00s, 8 D10s, Done. (141.2ms) Inference, (0.8ms) NMS
# 4 D00s, 10 D10s, Done. (139.3ms) Inference, (0.7ms) NMS
# Done. (136.2ms) Inference, (0.2ms) NMS
# 286 D00s, 14 D40s, Done. (137.1ms) Inference, (0.9ms) NMS
# Done. (137.1ms) Inference, (0.2ms) NMS
# 299 D00s, 1 D40, Done. (140.5ms) Inference, (0.9ms) NMS
# Done. (141.2ms) Inference, (0.2ms) NMS
# Done. (137.9ms) Inference, (0.1ms) NMS
# 10 D00s, Done. (138.8ms) Inference, (0.8ms) NMS
# 59 D00s, Done. (138.7ms) Inference, (0.8ms) NMS
# Done. (139.4ms) Inference, (0.2ms) NMS
# 281 D00s, 1 D10, 18 D20s, Done. (137.1ms) Inference, (0.8ms) NMS
# 28 D00s, 56 D40s, Done. (140.5ms) Inference, (0.8ms) NMS
# 285 D00s, Done. (136.2ms) Inference, (0.8ms) NMS
# 296 D00s, 1 D10, 3 D20s, Done. (136.3ms) Inference, (0.9ms) NMS
# Done. (139.5ms) Inference, (0.2ms) NMS
# 48 D00s, Done. (140.5ms) Inference, (0.8ms) NMS
# 3 D00s, Done. (139.1ms) Inference, (0.8ms) NMS
# 53 D00s, 27 D10s, Done. (136.3ms) Inference, (0.8ms) NMS
# 153 D00s, 147 D20s, Done. (139.9ms) Inference, (0.8ms) NMS
# Done. (141.0ms) Inference, (0.2ms) NMS
# 8 D00s, Done. (141.7ms) Inference, (0.8ms) NMS
# 288 D00s, 6 D10s, Done. (135.7ms) Inference, (0.8ms) NMS
# 79 D00s, 72 D10s, Done. (145.6ms) Inference, (0.9ms) NMS
# 1 D00, 55 D10s, Done. (142.5ms) Inference, (0.8ms) NMS
# Done. (142.4ms) Inference, (0.2ms) NMS
# Done. (141.6ms) Inference, (0.2ms) NMS
# 6 D00s, 1 D20, Done. (139.4ms) Inference, (0.8ms) NMS
# 161 D00s, Done. (136.7ms) Inference, (0.7ms) NMS
# 93 D00s, Done. (139.5ms) Inference, (0.8ms) NMS
# 91 D00s, 29 D10s, Done. (139.6ms) Inference, (0.8ms) NMS
# Done. (140.4ms) Inference, (0.2ms) NMS
# 288 D00s, 12 D40s, Done. (139.2ms) Inference, (0.8ms) NMS
# 300 D00s, Done. (140.1ms) Inference, (0.9ms) NMS
# 46 D00s, Done. (148.6ms) Inference, (0.8ms) NMS
# 43 D00s, 8 D10s, Done. (139.1ms) Inference, (0.8ms) NMS
# 100 D00s, 9 D40s, Done. (136.7ms) Inference, (0.8ms) NMS
# 34 D00s, Done. (142.9ms) Inference, (0.8ms) NMS
# 155 D00s, Done. (143.0ms) Inference, (0.9ms) NMS
# 30 D00s, 18 D10s, Done. (143.1ms) Inference, (0.8ms) NMS
# 283 D00s, Done. (142.8ms) Inference, (0.9ms) NMS
# Done. (140.5ms) Inference, (0.2ms) NMS
# 18 D10s, Done. (138.3ms) Inference, (0.8ms) NMS
# 20 D00s, Done. (136.9ms) Inference, (0.7ms) NMS
# 28 D00s, Done. (140.2ms) Inference, (0.8ms) NMS
# 6 D00s, 13 D10s, 31 D40s, Done. (136.4ms) Inference, (0.7ms) NMS
# 248 D00s, 29 D10s, Done. (142.3ms) Inference, (0.8ms) NMS
# 3 D00s, Done. (141.2ms) Inference, (0.8ms) NMS
# 2 D00s, Done. (139.2ms) Inference, (0.8ms) NMS
# Done. (140.1ms) Inference, (0.2ms) NMS
# 2 D00s, Done. (139.3ms) Inference, (0.8ms) NMS
# 300 D00s, Done. (139.0ms) Inference, (0.8ms) NMS
# 300 D00s, Done. (137.1ms) Inference, (0.9ms) NMS
# 199 D00s, Done. (138.4ms) Inference, (0.8ms) NMS
# 70 D00s, Done. (140.5ms) Inference, (0.9ms) NMS
# 23 D00s, Done. (138.2ms) Inference, (0.8ms) NMS
# Done. (136.4ms) Inference, (0.2ms) NMS
# 26 D00s, 148 D20s, Done. (139.5ms) Inference, (0.8ms) NMS
# 250 D00s, 2 D10s, Done. (141.9ms) Inference, (0.8ms) NMS
# 84 D00s, 12 D10s, Done. (139.6ms) Inference, (0.8ms) NMS
# 33 D00s, Done. (140.9ms) Inference, (0.9ms) NMS
# 17 D00s, Done. (138.6ms) Inference, (0.7ms) NMS
# Done. (136.6ms) Inference, (0.1ms) NMS
# Done. (139.6ms) Inference, (0.2ms) NMS
# Done. (139.1ms) Inference, (0.2ms) NMS
# Done. (141.1ms) Inference, (0.2ms) NMS
# 139 D00s, Done. (139.1ms) Inference, (0.8ms) NMS
# 256 D00s, 44 D10s, Done. (139.0ms) Inference, (0.8ms) NMS
# 17 D00s, 36 D10s, Done. (140.6ms) Inference, (0.8ms) NMS
# 205 D00s, 95 D10s, Done. (137.9ms) Inference, (0.8ms) NMS
# 30 D00s, Done. (143.7ms) Inference, (0.8ms) NMS
# 22 D10s, Done. (136.9ms) Inference, (0.7ms) NMS
# Done. (139.5ms) Inference, (0.1ms) NMS
# Done. (138.0ms) Inference, (0.2ms) NMS
# Done. (138.2ms) Inference, (0.2ms) NMS
# 110 D00s, Done. (140.6ms) Inference, (0.9ms) NMS
# Done. (404.134s)

# %% [markdown]
# # Convert labels to sumission format

# %%
c
# Out:
# 'Norway1'

# %%
def convert_yolo_to_pascal(yolo, img_h, img_w, img_h_o, img_w_o, c):
    c_x, c_y, w, h = yolo
    c_x1 = c_x*img_w
    c_y1 = c_y*img_h
    w1 = w*img_w
    h1 = h*img_h
    x_min = int(c_x1 - w1/2)
    y_min = int(c_y1 - h1/2)
    x_max = int(c_x1 + w1/2)
    y_max = int(c_y1 + h1/2)
    
    if x_min < 0:
        x_min = 0
    if y_min < 0:
        y_min = 0
    if x_max > img_w:
        x_max = img_w
    if y_max > img_h:
        y_max = img_h
    if c == "Norway1":
        y_min = y_min + (img_h_o-1824)
        y_max = y_max + (img_h_o-1824)
    return [x_min, y_min, x_max, y_max]

# %%
from PIL import Image
def convert_to_submission(file, c, min_conf={1: 0, 2:0, 3:0, 4:0}):
    img_id = os.path.splitext(os.path.basename(file))[0] + ".jpg"
    o_str = ""
    with open(file, "r") as f:
        output_str = []
        lines = f.read().splitlines()
        outputs = []
        img = Image.open(os.path.join(input_dir,c, "test/images", img_id))
        img_w, img_h = img.size
        img_w_o = img_w
        img_h_o = img_h
        if c == "Norway1":
            img_w_o, img_h_o = Image.open(os.path.join(input_dir, "Norway", "test/images", img_id)).size
            
        for line in lines:
            parts = line.split(' ')
            class_lbl = int(parts[0]) + 1
            yolo = [float(_) for _ in parts[1:5]]
            conf = 0
            if len(parts)==6:
                conf = float(parts[5])
            if conf >= min_conf[class_lbl]: # only add results if it is greater than min conf
              # # switch label
              # if class_lbl == 1 and conf <= min_conf[class_lbl] + 0.1:
              #   class_lbl = 2
              outputs.append([class_lbl, yolo, conf])

            # else:
            #   if conf >= 0.375 and class_lbl == 1:
            #       class_lbl = 2
            #       outputs.append([class_lbl, yolo, conf])
            #   if conf >= 0.32 and class_lbl == 2:
            #     class_lbl = 1
            #     outputs.append([class_lbl, yolo, conf])
                

        
        outputs.sort(key=lambda x: -x[2]) # sort by higher confidence first
        for x in outputs:
            class_lbl = x[0]
            yolo = x[1]
            pascal = convert_yolo_to_pascal(yolo, img_h, img_w, img_h_o, img_w_o, c)
            output_str += ([class_lbl] + pascal)
        o_str = " ".join([str(_) for _ in output_str])
    return img_id,o_str

# %%
import pdb
def get_results_for_countries(countries, detect_model_name, output_file, detect_runs="", min_conf={1:0,2:0, 3:0,4:0}):
    all_detected = {}
    for c in countries:
        files = glob.glob(f"runs/detect/{detect_model_name}{detect_runs}/labels/*.txt")
        for f in files:
            img_id, o_str = convert_to_submission(f, c, min_conf)
            all_detected[img_id] = o_str
    all_outs = []
    
    for c in countries:
        files = glob.glob(os.path.join(input_dir, c, "test/images", "*.jpg"))
        for f in files:
            img_id = os.path.basename(f)
            o_str = all_detected[img_id] if img_id in all_detected else ""
            all_outs.append(f"{img_id},{o_str}")
    
    
    with open(output_file, "w") as f:
        for l in all_outs:
            f.write(l + "\n")
        print(f"Wrote {output_file}")

# %%
detect_model_name = "Norway1"
detect_runs = "11" # changed to ensemble 3 models

# %%
for x in (.44, .46):
    get_results_for_countries([c], detect_model_name, c+"{:.3f}".format(x)+".txt", detect_runs=detect_runs, min_conf={1: x, 2:x, 3:x, 4:x})
# Out:
# Wrote Norway10.440.txt
# Wrote Norway10.460.txt

# %%
x = .45
get_results_for_countries([c], detect_model_name, c+"{:.3f}".format(x)+".txt", detect_runs=detect_runs, min_conf={1: x+0.05, 2:x, 3:x, 4:x})
# Out:
# Wrote Norway10.450.txt

# %% [markdown]
# # Fine Tuning

# %%
# Prepare the data
data_dir = f"../RDD2022_1/"

# %%
os.path.join(data_dir, c, 'images/train', f"{c}*.jpg")
# Out:
# '../RDD2022_1/Norway1/images/train/Norway1*.jpg'

# %%
c_files = glob.glob(os.path.join(data_dir, c, 'images/train', f"{c}*.jpg"))

# %%
len(c_files)
# Out:
# 0

# %%
c_files = [os.path.abspath(f) for f in c_files]

# %%
with open(os.path.join(data_dir, c, "train.txt"), "w") as f:
    for l in c_files:
        f.write(l+"\n")

# %%
# !python -m torch.distributed.launch --nproc_per_node 2 --master_port 9527 train.py --workers 2 --device 0,1 --sync-bn --batch-size 32 --data data/Japan.finetune.yaml --img 512 608 --cfg cfg/training/yolov7-custom.yaml --weights runs/train/yolov7Japan4/weights/best.pt --name yolov7JapanFineTune --hyp data/hyp.scratch.p5.custom.finetune.yaml --epoch 50
# Out:
# /home/pham/anaconda3/lib/python3.7/site-packages/torch/distributed/launch.py:186: FutureWarning: The module torch.distributed.launch is deprecated
# and will be removed in future. Use torchrun.
# Note that --use_env is set by default in torchrun.
# If your script expects `--local_rank` argument to be set, please
# change it to read from `os.environ['LOCAL_RANK']` instead. See
# https://pytorch.org/docs/stable/distributed.html#launch-utility for
# further instructions
#
#   FutureWarning,
# WARNING:torch.distributed.run:
# *****************************************
# Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# *****************************************
# YOLOR 🚀 v0.1-107-g44d8ab4 torch 1.12.1 CUDA:0 (NVIDIA RTX A4000, 16117.3125MB)
#                                        CUDA:1 (NVIDIA RTX A4000, 16108.875MB)
#
# Added key: store_based_barrier_key:1 to store for rank: 0
# Rank 0: Completed store-based barrier for key:store_based_barrier_key:1 with 2 nodes.
# Namespace(adam=False, artifact_alias='latest', batch_size=16, bbox_interval=-1, bucket='', cache_images=False, cfg='cfg/training/yolov7-custom.yaml', data='data/Japan.finetune.yaml', device='0,1', entity=None, epochs=50, evolve=False, exist_ok=False, freeze=[0], global_rank=0, hyp='data/hyp.scratch.p5.custom.finetune.yaml', image_weights=False, img_size=[512, 608], label_smoothing=0.0, linear_lr=False, local_rank=0, multi_scale=False, name='yolov7JapanFineTune', noautoanchor=False, nosave=False, notest=False, project='runs/train', quad=False, rect=False, resume=False, save_dir='runs/train/yolov7JapanFineTune', save_period=-1, single_cls=False, sync_bn=True, total_batch_size=32, upload_dataset=False, weights='runs/train/yolov7Japan4/weights/best.pt', workers=2, world_size=2)
# tensorboard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# hyperparameters: lr0=0.01, lrf=0.1, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.3, cls_pw=1.0, obj=0.7, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.2, scale=0.1, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=0.0, mixup=0.0, copy_paste=0.0, paste_in=0.0, loss_ota=1
# wandb: Currently logged in as: phamvanvung. Use `wandb login --relogin` to force relogin
# wandb: wandb version 0.13.2 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.13.1
# wandb: Run data is saved locally in /home/pham/Documents/SHSU/Researching/roaddamagedetector/yolov7/wandb/run-20220907_171352-1z34ovjk
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run yolov7JapanFineTune
# wandb: ⭐️ View project at https://wandb.ai/phamvanvung/YOLOR
# wandb: 🚀 View run at https://wandb.ai/phamvanvung/YOLOR/runs/1z34ovjk
#
#                  from  n    params  module                                  arguments
#   0                -1  1       928  models.common.Conv                      [3, 32, 3, 1]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     36992  models.common.Conv                      [64, 64, 3, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  1      8320  models.common.Conv                      [128, 64, 1, 1]
#   5                -2  1      8320  models.common.Conv                      [128, 64, 1, 1]
#   6                -1  1     36992  models.common.Conv                      [64, 64, 3, 1]
#   7                -1  1     36992  models.common.Conv                      [64, 64, 3, 1]
#   8                -1  1     36992  models.common.Conv                      [64, 64, 3, 1]
#   9                -1  1     36992  models.common.Conv                      [64, 64, 3, 1]
#  10  [-1, -3, -5, -6]  1         0  models.common.Concat                    [1]
#  11                -1  1     66048  models.common.Conv                      [256, 256, 1, 1]
#  12                -1  1         0  models.common.MP                        []
#  13                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  14                -3  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  16          [-1, -3]  1         0  models.common.Concat                    [1]
#  17                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  18                -2  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  19                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  20                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  21                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  22                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  23  [-1, -3, -5, -6]  1         0  models.common.Concat                    [1]
#  24                -1  1    263168  models.common.Conv                      [512, 512, 1, 1]
#  25                -1  1         0  models.common.MP                        []
#  26                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  27                -3  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  28                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  29          [-1, -3]  1         0  models.common.Concat                    [1]
#  30                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  31                -2  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  32                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  33                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  34                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  35                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  36  [-1, -3, -5, -6]  1         0  models.common.Concat                    [1]
#  37                -1  1   1050624  models.common.Conv                      [1024, 1024, 1, 1]
#  38                -1  1         0  models.common.MP                        []
#  39                -1  1    525312  models.common.Conv                      [1024, 512, 1, 1]
#  40                -3  1    525312  models.common.Conv                      [1024, 512, 1, 1]
#  41                -1  1   2360320  models.common.Conv                      [512, 512, 3, 2]
#  42          [-1, -3]  1         0  models.common.Concat                    [1]
#  43                -1  1    262656  models.common.Conv                      [1024, 256, 1, 1]
#  44                -2  1    262656  models.common.Conv                      [1024, 256, 1, 1]
#  45                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  46                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  47                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  48                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  49  [-1, -3, -5, -6]  1         0  models.common.Concat                    [1]
#  50                -1  1   1050624  models.common.Conv                      [1024, 1024, 1, 1]
#  51                -1  1   7609344  models.common.SPPCSPC                   [1024, 512, 1]
#  52                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  53                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  54                37  1    262656  models.common.Conv                      [1024, 256, 1, 1]
#  55          [-1, -2]  1         0  models.common.Concat                    [1]
#  56                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  57                -2  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  58                -1  1    295168  models.common.Conv                      [256, 128, 3, 1]
#  59                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  60                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  61                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  62[-1, -2, -3, -4, -5, -6]  1         0  models.common.Concat                    [1]
#  63                -1  1    262656  models.common.Conv                      [1024, 256, 1, 1]
#  64                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  65                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  66                24  1     65792  models.common.Conv                      [512, 128, 1, 1]
#  67          [-1, -2]  1         0  models.common.Concat                    [1]
#  68                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  69                -2  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  70                -1  1     73856  models.common.Conv                      [128, 64, 3, 1]
#  71                -1  1     36992  models.common.Conv                      [64, 64, 3, 1]
#  72                -1  1     36992  models.common.Conv                      [64, 64, 3, 1]
#  73                -1  1     36992  models.common.Conv                      [64, 64, 3, 1]
#  74[-1, -2, -3, -4, -5, -6]  1         0  models.common.Concat                    [1]
#  75                -1  1     65792  models.common.Conv                      [512, 128, 1, 1]
#  76                -1  1         0  models.common.MP                        []
#  77                -1  1     16640  models.common.Conv                      [128, 128, 1, 1]
#  78                -3  1     16640  models.common.Conv                      [128, 128, 1, 1]
#  79                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  80      [-1, -3, 63]  1         0  models.common.Concat                    [1]
#  81                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  82                -2  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  83                -1  1    295168  models.common.Conv                      [256, 128, 3, 1]
#  84                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  85                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  86                -1  1    147712  models.common.Conv                      [128, 128, 3, 1]
#  87[-1, -2, -3, -4, -5, -6]  1         0  models.common.Concat                    [1]
#  88                -1  1    262656  models.common.Conv                      [1024, 256, 1, 1]
#  89                -1  1         0  models.common.MP                        []
#  90                -1  1     66048  models.common.Conv                      [256, 256, 1, 1]
#  91                -3  1     66048  models.common.Conv                      [256, 256, 1, 1]
#  92                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  93      [-1, -3, 51]  1         0  models.common.Concat                    [1]
#  94                -1  1    525312  models.common.Conv                      [1024, 512, 1, 1]
#  95                -2  1    525312  models.common.Conv                      [1024, 512, 1, 1]
#  96                -1  1   1180160  models.common.Conv                      [512, 256, 3, 1]
#  97                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  98                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
#  99                -1  1    590336  models.common.Conv                      [256, 256, 3, 1]
# 100[-1, -2, -3, -4, -5, -6]  1         0  models.common.Concat                    [1]
# 101                -1  1   1049600  models.common.Conv                      [2048, 512, 1, 1]
# 102                75  1    328704  models.common.RepConv                   [128, 256, 3, 1]
# 103                88  1   1312768  models.common.RepConv                   [256, 512, 3, 1]
# 104               101  1   5246976  models.common.RepConv                   [512, 1024, 3, 1]
# 105   [102, 103, 104]  1     50338  models.yolo.IDetect                     [4, [[12, 16, 19, 36, 40, 28], [36, 75, 76, 55, 72, 146], [142, 110, 192, 243, 459, 401]], [256, 512, 1024]]
# Model Summary: 415 layers, 37212738 parameters, 37212738 gradients
#
# Transferred 564/566 items from runs/train/yolov7Japan4/weights/best.pt
# Scaled weight_decay = 0.0005
# Optimizer groups: 95 .bias, 95 conv.weight, 98 other
# Using SyncBatchNorm()
# train: Scanning '../RDD2022_1/Japan/train.cache' images and labels... 7110 found
# train: Scanning '../RDD2022_1/Japan/train.cache' images and labels... 7110 found
# val: Scanning '../RDD2022_1/Japan/labels/val.cache' images and labels... 790 fou
#
# autoanchor: Analyzing anchors... anchors/target = 4.45, Best Possible Recall (BPR) = 0.9979
# Image sizes 512 train, 608 test
# Using 2 dataloader workers
# Logging results to runs/train/yolov7JapanFineTune
# Starting training for 50 epochs...
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#       0/49     8.43G   0.03469  0.005437  0.006014   0.04614        29       512Reducer buckets have been rebuilt in this iteration.
#       0/49     8.28G   0.03386  0.004695  0.001746    0.0403         7       512
#                Class      Images      Labels           P           R      mAP@.5/home/pham/anaconda3/lib/python3.7/site-packages/torch/functional.py:478: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  /opt/conda/conda-bld/pytorch_1659484809535/work/aten/src/ATen/native/TensorShape.cpp:2894.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
#                Class      Images      Labels           P           R      mAP@.5
#                  all         790        1709       0.583       0.578       0.597       0.266
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#       1/49     8.35G   0.03353  0.004495  0.001581    0.0396         7       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         790        1709       0.596       0.547       0.585       0.261
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#       2/49     8.35G   0.03391  0.004643  0.001495   0.04005         4       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         790        1709       0.539       0.581        0.56       0.234
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#       3/49     8.35G   0.03499  0.004648  0.001752   0.04139         3       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         790        1709        0.51       0.503       0.492       0.211
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#       4/49     8.35G   0.03695  0.004964  0.002399   0.04431        14       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         790        1709       0.533       0.484       0.482       0.199
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#       5/49     8.35G   0.03813  0.005032  0.002686   0.04585         4       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         790        1709       0.478       0.501       0.461       0.185
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#       6/49     8.35G   0.03787  0.004952  0.002335   0.04515         3       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         790        1709       0.535       0.447        0.46       0.186
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#       7/49     8.35G   0.03764    0.0049  0.002329   0.04487         4       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         790        1709        0.51       0.514       0.486       0.201
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#       8/49     8.35G   0.03684  0.004779  0.002012   0.04363         5       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         790        1709       0.525       0.525       0.506         0.2
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#       9/49     8.35G   0.03661  0.004904   0.00203   0.04355         7       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         790        1709       0.497         0.5       0.473       0.191
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      10/49     8.35G   0.03643  0.004725  0.001796   0.04295         6       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         790        1709       0.509       0.531       0.501       0.205
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      11/49     8.35G   0.03641  0.004766   0.00195   0.04312         5       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         790        1709       0.566       0.482       0.496        0.21
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      12/49     8.35G   0.03571  0.004691  0.001827   0.04223         7       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         790        1709       0.494       0.525       0.504       0.214
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      13/49     8.35G   0.03561  0.004709  0.001701   0.04202         6       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         790        1709       0.513       0.529       0.506       0.214
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      14/49     8.35G   0.03494  0.004638  0.001821    0.0414         4       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         790        1709       0.554       0.495       0.508       0.209
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      15/49     8.35G   0.03446  0.004696  0.001484   0.04064         4       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         790        1709        0.55       0.482       0.488       0.203
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      16/49     8.35G   0.03442  0.004579  0.001506    0.0405         5       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         790        1709       0.523       0.533       0.525       0.223
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      17/49     8.35G   0.03409  0.004663  0.001218   0.03997         6       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         790        1709       0.495       0.564       0.522       0.221
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      18/49     8.35G   0.03362  0.004555  0.001413   0.03959        10       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         790        1709       0.492        0.55       0.509       0.207
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      19/49     8.35G    0.0333  0.004533  0.001315   0.03914         4       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         790        1709       0.553       0.509       0.507       0.213
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      20/49     8.35G   0.03313  0.004482  0.001228   0.03884         6       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         790        1709       0.538       0.516         0.5       0.212
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      21/49     8.35G   0.03287  0.004456  0.001126   0.03846         5       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         790        1709       0.532       0.537        0.52       0.218
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      22/49     8.35G    0.0323  0.004484  0.001119    0.0379         7       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         790        1709       0.519       0.553       0.525        0.22
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      23/49     8.35G   0.03215  0.004426  0.001134   0.03771         6       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         790        1709       0.513       0.569        0.53       0.225
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      24/49     8.35G   0.03139  0.004312 0.0008908   0.03659         4       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         790        1709       0.539       0.532       0.517        0.22
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      25/49     8.35G   0.03092  0.004336 0.0009156   0.03617         8       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         790        1709       0.554       0.533       0.521       0.223
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      26/49     8.35G   0.03063  0.004272  0.001029   0.03593         8       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         790        1709       0.547       0.529       0.515       0.219
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      27/49     8.35G   0.03023  0.004269 0.0009167   0.03542         6       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         790        1709       0.541       0.547       0.526       0.222
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      28/49     8.35G   0.02968  0.004136 0.0006895    0.0345         3       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         790        1709       0.514       0.577       0.525       0.226
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      29/49     8.35G   0.02898  0.004048  0.000743   0.03377         3       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         790        1709       0.518        0.59       0.538       0.225
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      30/49     8.35G   0.02877    0.0041 0.0007465   0.03362         4       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         790        1709       0.553        0.53       0.533       0.222
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      31/49     8.35G   0.02832  0.003987  0.000586    0.0329         2       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         790        1709       0.527       0.571       0.538       0.228
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      32/49     8.35G   0.02757   0.00389  0.000659   0.03212         4       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         790        1709       0.563       0.541       0.541       0.231
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      33/49     8.35G   0.02764   0.00395 0.0006367   0.03222         9       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         790        1709       0.537       0.543       0.532       0.228
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      34/49     8.35G   0.02691  0.003875  0.000533   0.03132         5       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         790        1709       0.516        0.58       0.531       0.224
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      35/49     8.35G   0.02659  0.003861 0.0005247   0.03097         6       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         790        1709       0.534       0.546        0.52       0.223
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      36/49     8.35G   0.02603  0.003702  0.000571    0.0303         5       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         790        1709       0.527       0.559       0.532       0.226
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      37/49     8.35G   0.02569  0.003703 0.0004412   0.02983         7       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         790        1709       0.543       0.548       0.517       0.219
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      38/49     8.35G   0.02499   0.00356 0.0004817   0.02903         8       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         790        1709        0.57       0.511       0.517       0.217
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      39/49     8.35G    0.0244  0.003543 0.0004339   0.02838         7       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         790        1709       0.561       0.537       0.516       0.218
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      40/49     8.35G   0.02411  0.003538 0.0003576   0.02801         5       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         790        1709       0.564       0.527       0.526       0.217
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      41/49     8.35G   0.02363  0.003525 0.0004521    0.0276         3       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         790        1709       0.555       0.549       0.531       0.224
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      42/49     8.35G   0.02313  0.003394 0.0003998   0.02692         3       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         790        1709       0.531       0.561       0.522       0.224
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      43/49     8.35G   0.02289  0.003355 0.0004719   0.02671         3       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         790        1709       0.551       0.534       0.524       0.221
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      44/49     8.35G   0.02257  0.003397 0.0003347    0.0263         5       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         790        1709       0.535       0.556       0.526       0.223
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      45/49     8.35G   0.02224  0.003312 0.0003186   0.02587         6       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         790        1709       0.601       0.507       0.537       0.225
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      46/49     8.35G   0.02209  0.003315 0.0002947    0.0257         8       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         790        1709       0.589       0.522       0.536       0.225
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      47/49     8.35G   0.02138  0.003316 0.0003204   0.02502         6       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         790        1709       0.573       0.527       0.537       0.223
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      48/49     8.35G   0.02153  0.003239 0.0003529   0.02512         5       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         790        1709       0.577       0.524       0.535       0.221
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#      49/49     8.35G   0.02123  0.003237 0.0002839   0.02475        13       512
#                Class      Images      Labels           P           R      mAP@.5
#                  all         790        1709       0.536       0.562       0.535       0.223
#                  D00         790         413       0.482       0.535       0.495       0.189
#                  D10         790         434       0.498       0.484       0.434       0.158
#                  D20         790         634       0.572       0.617       0.586       0.278
#                  D40         790         228       0.594       0.614       0.627       0.266
# 50 epochs completed in 1.584 hours.
#
# Optimizer stripped from runs/train/yolov7JapanFineTune/weights/last.pt, 74.8MB
# Optimizer stripped from runs/train/yolov7JapanFineTune/weights/best.pt, 74.8MB
# Images sizes do not match. This will causes images to be display incorrectly in the UI.
# wandb: Waiting for W&B process to finish... (success).
# wandb:
# wandb:
# wandb: Run history:
# wandb:      metrics/mAP_0.5 █▇▆▃▁▁▂▃▃▃▃▃▂▄▄▃▃▄▄▅▄▄▄▄▅▅▅▅▄▅▄▄▄▅▄▄▅▅▅▅
# wandb: metrics/mAP_0.5:0.95 ██▅▃▁▁▂▂▃▃▃▄▂▄▄▃▃▄▄▄▄▄▄▅▄▅▅▅▄▅▄▄▄▄▄▄▄▄▄▄
# wandb:    metrics/precision ▇█▄▃▁▄▃▄▃▆▂▃▅▄▂▂▄▄▃▃▅▅▅▃▅▄▆▄▄▄▅▆▆▅▄▅█▇▆▄
# wandb:       metrics/recall █▆█▄▄▁▅▅▅▃▅▅▃▆▇▆▅▆▇▇▅▅▆█▅▇▆▆▆▇▆▄▅▆▇▆▄▅▅▇
# wandb:       train/box_loss ▆▆▆▇███▇▇▇▇▇▆▆▆▆▆▆▆▆▅▅▅▄▄▄▄▄▃▃▃▃▂▂▂▂▁▁▁▁
# wandb:       train/cls_loss ▅▅▅▅█▇▇▆▅▆▅▅▄▅▄▄▄▃▃▃▃▃▃▂▂▂▂▂▂▂▁▂▁▁▁▂▁▁▁▁
# wandb:       train/obj_loss ▇▆▆▇██▇▇▇▇▇▇▇▆▇▆▆▆▆▆▅▅▅▅▄▄▄▄▃▃▃▂▂▂▂▁▁▁▁▁
# wandb:         val/box_loss ▁▁▂▄██▆▅▆▆▆▆▅▄▄▅▅▄▄▄▄▄▃▄▄▃▃▃▃▃▃▃▄▃▃▃▃▃▃▃
# wandb:         val/cls_loss ▁▂▃▇▂▅▁▁▆▆▃▄▆▃▂▄▃▅▂▄▃▃▄▄▅▄▄▅▅▇▇▇█▆▆▇▇██▇
# wandb:         val/obj_loss ▁▂▂▂▁▂▁▁▂▁▁▂▂▂▂▃▂▃▃▃▃▄▄▄▅▅▅▅▅▆▆▇▇▇▇▇█▇██
# wandb:                x/lr0 ▂▄▅▇█████▇▇▇▇▇▆▆▆▆▅▅▅▅▄▄▄▃▃▃▃▂▂▂▂▂▂▁▁▁▁▁
# wandb:                x/lr1 ▂▄▅▇█████▇▇▇▇▇▆▆▆▆▅▅▅▅▄▄▄▃▃▃▃▂▂▂▂▂▂▁▁▁▁▁
# wandb:                x/lr2 █▆▄▃▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:
# wandb: Run summary:
# wandb:      metrics/mAP_0.5 0.53545
# wandb: metrics/mAP_0.5:0.95 0.22295
# wandb:    metrics/precision 0.53635
# wandb:       metrics/recall 0.56248
# wandb:       train/box_loss 0.02123
# wandb:       train/cls_loss 0.00028
# wandb:       train/obj_loss 0.00324
# wandb:         val/box_loss 0.05283
# wandb:         val/cls_loss 0.0173
# wandb:         val/obj_loss 0.01131
# wandb:                x/lr0 0.00104
# wandb:                x/lr1 0.00104
# wandb:                x/lr2 0.00104
# wandb:
# wandb: Synced yolov7JapanFineTune: https://wandb.ai/phamvanvung/YOLOR/runs/1z34ovjk
# wandb: Synced 6 W&B file(s), 342 media file(s), 1 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20220907_171352-1z34ovjk/logs

# %%
#!python -m torch.distributed.launch --nproc_per_node 2 --master_port 9527 train.py --workers 2 --device 0,1 --sync-bn --batch-size 32 --data data/Japan.finetune.yaml --img 512 608 --cfg cfg/training/yolov7-custom.yaml --weights '' --name yolov7JapanScratch --hyp data/hyp.scratch.p5.custom.finetune.yaml --epoch 50
